# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Softmax
import matplotlib.pyplot as plt
import networkx as nx
from scipy.stats import ks_2samp
from graph_utils import avg_path_length
from graph_utils import get_cluster_coeff
import pandas as pd

# %%
#Run me

nA = 5
class Node:
    '''kekw'''
    def __init__(self, Q):
        self.Q = Q #Q-func
        self.E = [] #Experience pool

def initQ(in_size, i, lr):
    '''Initializes Q-approximator for 
     - in_size : Size of input (should be number of states + number of actions)
     - i : 
    '''
    input_layer = Input(shape = (in_size,))
    dense_1 = Dense(128, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(input_layer)
    dense_2 = Dense(128, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(dense_1)
    dense_3 = Dense(64, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(dense_2)
    o = Dense(1, activation = None, use_bias = True, kernel_initializer="glorot_uniform")(dense_3)
    
    Q = Model(input_layer, o, name = "Q" + str(i))

#     def mse(y_true, y_pred):
#         return tf.math.reduce_mean(tf.math.square(y_true - y_pred)) * 0.5
    
    optimizer = tf.keras.optimizers.SGD(learning_rate = lr, momentum = 0.0)
    loss =  tf.keras.losses.MeanSquaredError()

    Q.compile(loss = loss, optimizer = optimizer)
                           
    return Q

class World:
    def __init__(self, n, num_agents):
        #self.state = np.zeros((num_agents, n * n)) #State, 46 x 100
        self.state_nums = np.zeros((num_agents,), dtype = int)
        self.n = n
        self.G = nx.Graph()
        self.G.add_nodes_from(range(num_agents))
        self.num_agents = num_agents
        
        for m in range(num_agents): #Start agents in random states
            r = np.random.randint(0, n * n)
            #self.state[m, r] = 1
            self.state_nums[m] = r
    
    def get_pos(self):
        out = []
        for i in range(self.num_agents):
            loc = self.state_nums[i]
            y, x = loc // self.n, loc % self.n
            x += np.random.uniform()
            y += np.random.uniform()
            out.append((x, y))
        return dict(enumerate(out, start = 0))
        
    def update_G(self):
        '''
        Searches for agents in the same state, and adds one to their edge's weight
        Also decreases any existing connections that are not maintained's weights by 1
        Removes any connections that have weight leq to 0
        '''
        updated = []
        rewards = np.zeros((self.num_agents, 1))
        for ag in range(self.state_nums.shape[0]): 
            #TODO: Maybe replace with np where to add edges?
            for tg in range(self.state_nums.shape[0]):
                #If same state, create/add weight to edge
                if ag != tg and self.state_nums[ag] == self.state_nums[tg] and (tg, ag) not in updated: 
                    if not self.G.has_edge(ag, tg):            #^ that fixes the double counhting but if i leave it
                        self.G.add_edge(ag, tg, weight = 1)  #it has better time complexity
                    else:
                        self.G.edges[ag, tg]['weight'] += 1 #<- thats why theyre 0.5 
                    updated.append((ag, tg))
                    updated.append((tg, ag))
                    
        for edge in self.G.edges():
            #Decrement all unupdated edges by 1, remove if less than 0
            if edge not in updated:
                self.G.edges[edge]['weight'] -= 0.005
                if self.G.edges[edge]['weight'] <= 0:
                    self.G.remove_edge(edge[0], edge[1])
                else:
                    rewards[edge[0]] += self.G.edges[edge]['weight']
                    rewards[edge[1]] += self.G.edges[edge]['weight']
            else:
                rewards[edge[0]] += self.G.edges[edge]['weight']
                rewards[edge[1]] += self.G.edges[edge]['weight']
            
        return rewards
    
                    
    def take_action(self, agent_id, a):
        #loc = np.argmax(self.state[agent_id, :])
        loc = self.state_nums[agent_id]
        y, x = loc // self.n, loc % self.n
        
        if a == 4: #down
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y + 1) * self.n) + x] = 1
            self.state_nums[agent_id] = ((y + 1) * self.n) + x
        elif a == 1: #up
           # self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y - 1) * self.n) + x] = 1
            self.state_nums[agent_id] = ((y - 1) * self.n) + x
        elif a == 2: #left
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y) * self.n) + x - 1] = 1
            self.state_nums[agent_id] = ((y) * self.n) + x - 1
        elif a == 3: #right
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y) * self.n) + x + 1] = 1  
            self.state_nums[agent_id] = ((y) * self.n) + x + 1
        elif a == 0: #stay
            pass

def get_legals(s, n, nA):
    #Returns an array containig infinity if legal negative infinity if not
    legal_moves = np.ones((nA, 1)) * np.inf
    loc = s #np.argmax(s)
    y, x = loc // n, loc % n
    if y >= n - 1:
        legal_moves[4] = -np.inf
    if y == 0:
        legal_moves[1] = -np.inf
    if x == 0:
        legal_moves[2] = -np.inf
    if x == n - 1:
        legal_moves[3] = -np.inf

    return legal_moves
    
    #Make the graph pretty
def pp_graph(GRAPH_NAME, pos):
    #not short for pee pee graph
    widths = nx.get_edge_attributes(GRAPH_NAME, 'weight')
    nodelist = GRAPH_NAME.nodes()

    plt.figure(figsize=(10,10))

    #pos = nx.spring_layout(GRAPH_NAME)
    nx.draw_networkx_nodes(GRAPH_NAME, pos,
                           nodelist=nodelist,
                           node_size=100,
                           alpha=0.7)
    nx.draw_networkx_edges(GRAPH_NAME, pos,
                           edgelist = widths.keys(),
                           width=[val*1 for val in list(widths.values())],
                           edge_color='black',
                           alpha=0.75)
    plt.box(False)
    plt.show() 

    
def form_2d_graph(snums):
    xout, yout = [], []
    for s in snums:
        y, x = s // n, s % n
        xout.append((x + np.random.uniform())* 10)
        yout.append((y + np.random.uniform()) * 10)
    
    return xout, yout

def plot_2d_graph(x, y):
    fig = plt.figure()
    ax = fig.gca()
    ax.set_xticks(np.arange(0, 100, 10))
    ax.set_yticks(np.arange(0, 100, 10))
    plt.scatter(x, y, s=10)
    plt.grid()
    plt.show()
    
def degree_distribution(graph, name = "bruh"):
    degree_sequence = sorted((d for _, d in graph.degree()), reverse=True)

    plt.figure(name, figsize=(8, 8))
    plt.bar(*np.unique(degree_sequence, return_counts=True))
    plt.xlabel('Degree')
    plt.ylabel('# of Nodes')

    plt.show()

# %%
def monk_it_up(epsilon_func, episode_length = 100, n = 10, y = 0.9, nAgents = 47, lr = 0.001, verbose = 1):
    '''
    Inputs:
     - epsilon_func: Function taht takes a timestep first, and then an agent id i, and returns a
                     epsilon between 0 and 1, keep in mind t starts at 0
     - episode_length: Number of steps in an episode
     - n: dimensions of world, will be nxn size
     - y: discount factor
     - nAgents: number of monkeys
     - lr: Learning rate, controls how fast neural net learns. Careful with putting lr too high, since 0.01 makes 
           gradient bounce around super fast, leading to a lot of nan predictions
     - verbose: 
         - if 0: prints nothing
         - if 1: prints Z-score and KSamps
         - if 2: prints graphs, z-score and Ksamps
           
    Returns:
    world object: Object representing the world, do world.G to get the graph, or world.state_nums for current board
                  state
    Avg path length list: List containing average path legnths every 10 timesteps (CURRENTLY NANS)
    clsuter_avgs: List containing average clustering coefficient every timestep
    zs : Numpy array of z-scores at each timestep (compared to our proximity graph, lower is better)
    samps : listo f KS-2  samples(tuples) at every timestep
    hist_gs : Graph of every timestep
    '''
    p_lengths = []
    cluster_avgs = []
    zs = []
    samps = []
    hist_gs = []
    
    worse_graph = nx.read_adjlist("./prog_g.adjlist")
    w_degree_sequence = np.unique(sorted((d for _, d in worse_graph.degree()), reverse=True), return_counts = True)[1]
    
    all_actions = np.eye(nA, dtype = np.float32)
    state = np.zeros((nA, n * n))
    vec = np.concatenate((state, all_actions), axis = 1)

    def policy(s, n, nA, epsilon, Q):
        legal_moves = get_legals(s, n, nA)
        #Epsilon exploration
        if np.random.uniform() < epsilon:
            r = np.random.randint(0, nA)
            while legal_moves[r] != np.inf:
                r = np.random.randint(0, nA)
            return r

        vec[:, s] = 1    
        out = np.argmax(np.minimum(Q(vec), legal_moves))
        vec[:, s] = 0

        return out

    upd_vec = np.zeros((1, n * n + nA))
    tg_vec = np.zeros((1, n * n + nA))

    def update(s, a, r, sp, gamma, Q):
        upd_vec[0, s] = 1
        upd_vec[0, s + a] = 1


        tg_vec[0, sp] = 1
        ap = policy(sp, n, nA, 0, Q)
        tg_vec[0, ap + sp] = 1
        Q.train_on_batch(upd_vec, r + gamma * Q(tg_vec))
        upd_vec[0, s], upd_vec[0, s + a], tg_vec[0, sp], tg_vec[0, ap + sp]  = 0, 0, 0, 0
        
    agents = [Node(initQ(n * n + nA, i, lr)) for i in range(nAgents)]

    world = World(n, nAgents)

    for t in range(episode_length):
        if t % 10 == 0 and verbose >= 1:
            print(f"Iter : {t}")
        

        for agent, i in zip(agents, range(nAgents)):
            epsilon = epsilon_func(t, i)
            sars = np.zeros((4,), dtype = int)
            s = world.state_nums[i]
            a = policy(s, n, nA, epsilon, agent.Q)

            world.take_action(i, a)

            sars[0] = s
            sars[1] = a
            sars[3] = world.state_nums[i]

            agent.E.append(sars) #r will come later

        R = world.update_G()

        for agent, i in zip(agents, range(nAgents)):
            agent.E[t][2] = R[i]
            s, a, r, sp = agent.E[np.random.choice(len(agent.E))]
            #s, a, r, sp = agent.E[t]
            #update(s, a, r, sp, y, agent.Q)
            
        p_len = None
        
        p_len = avg_path_length(world.G)
        p_lengths.append(p_len)
        if t % 5 == 0 and verbose >= 2:
            pp_graph(world.G, world.get_pos())
            print(f"Average path length: {p_len}")
            
        
        degree_sequence = np.unique(sorted((d for _, d in world.G.degree()), reverse=True),
                                    return_counts = True)[1]
        top = (degree_sequence.mean() - w_degree_sequence.mean()) 
        bot1 = np.square(np.std(degree_sequence) / np.sqrt(degree_sequence.shape[0]))
        bot2 = np.square(np.std(w_degree_sequence)) / np.sqrt(w_degree_sequence.shape[0])
        z = top / np.sqrt(bot1 + bot2)
        

        zs.append(z)

        s = ks_2samp(degree_sequence, w_degree_sequence)
        samps.append(s)
        if t % 10 == 0 and verbose >= 1:
            print(f"Z-score : {z}")
            print(f"ks_2 sample : {s}")

        if t % 50 == 0:
            hist_gs.append(world.G.copy())
        cluster_avgs.append(nx.average_clustering(world.G))
        
    return p_lengths, cluster_avgs, np.array(zs), samps, hist_gs

# %%
nAgents = 47
eps_funcs = np.random.uniform(0.2, 0.5, (nAgents,))
e_fixed = lambda t, i: 0.3
e_fixed_2 = lambda t, i: 0.4
e_decay = lambda t, i : 1 / (t + 1)
e_brainoff = lambda t, i: 1

res = [0] * 3

#250 Iters, -0.025
for e, j in zip([0.1, 0.5, 0.7], range(3)):
    res[j] = []
    for i in range(3):
        print(f"iter: {i}")
        p_lengths, cluster_avgs, zs, samps, hist_gs = monk_it_up(e_fixed, 1500, n  = 10, nAgents = 47,y = e, verbose = 0) #0.005
        res[j].append((p_lengths, cluster_avgs, zs, samps, hist_gs))
        #pp_graph(res[i][0].G, res[i][0].get_pos())
# Out:
# iter: 0
# iter: 1
# iter: 2
# iter: 0
# iter: 1
# iter: 2
# iter: 0
# iter: 1
# iter: 2

# %%
for iters in range(150, 1500, 10):  
    print(f"Iters: {iters}")
    for res_e in res:    
        mins = []
        stat = []
        p = []
        cluss = []
        pplens = []
        for run in res_e:
            plens, clus_avgs, zs, samp, _ = run
            mins.append(zs[iters])
            stat.append(samp[iters][0])
            p.append(samp[iters][1])
            cluss.append(clus_avgs[iters])
            pplens.append(plens[iters // 5])
        

        print(f"Average most recent Z-score: {np.mean(mins)}")
        print(f"Average most recent stat-score: {np.mean(stat)}")
        print(f"Average most recent p-value: {np.mean(p)}")
        print(f"Average most recent clustering coeff: {np.mean(cluss)}")
        print(f"Average most recent path length: {np.mean(pplens)}")
        print("\n")
# Out:
# Iters: 150
# Average most recent Z-score: 1.182184466599866
# Average most recent stat-score: 0.3052156177156177
# Average most recent p-value: 0.34005145970309253
# Average most recent clustering coeff: 0.5683476197513194
# Average most recent path length: 4.22837564669202
#
#
# Average most recent Z-score: 1.3383704372588718
# Average most recent stat-score: 0.4311668723433429
# Average most recent p-value: 0.11578895460856607
# Average most recent clustering coeff: 0.5528877481969592
# Average most recent path length: 4.230650632130743
#
#
# Iters: 160
# Average most recent Z-score: 1.2825630252701798
# Average most recent stat-score: 0.30790598290598287
# Average most recent p-value: 0.31478105425596886
# Average most recent clustering coeff: 0.5700435085118172
# Average most recent path length: 4.212539829376092
#
#
# Average most recent Z-score: 1.38209662944673
# Average most recent stat-score: 0.36130536130536134
# Average most recent p-value: 0.3321276663797796
# Average most recent clustering coeff: 0.5614482689099464
# Average most recent path length: 4.252235584335492
#
#
# Iters: 170
# Average most recent Z-score: 1.1507248712204068
# Average most recent stat-score: 0.2667388167388167
# Average most recent p-value: 0.4980039212495873
# Average most recent clustering coeff: 0.5714468195114388
# Average most recent path length: 4.086332956453215
#
#
# Average most recent Z-score: 1.1986758219579843
# Average most recent stat-score: 0.3394198394198394
# Average most recent p-value: 0.30468293246729816
# Average most recent clustering coeff: 0.571223942365754
# Average most recent path length: 4.232809127351218
#
#
# Iters: 180
# Average most recent Z-score: 0.9921992045001589
# Average most recent stat-score: 0.32044181308887193
# Average most recent p-value: 0.27704096160072883
# Average most recent clustering coeff: 0.5742271767838623
# Average most recent path length: 4.040908623702333
#
#
# Average most recent Z-score: 1.3113029547646822
# Average most recent stat-score: 0.3903351550410374
# Average most recent p-value: 0.14900635500166107
# Average most recent clustering coeff: 0.5733061095127429
# Average most recent path length: 4.176996608078939
#
#
# Iters: 190
# Average most recent Z-score: 0.9714866299079574
# Average most recent stat-score: 0.2757724301841949
# Average most recent p-value: 0.40330184905536487
# Average most recent clustering coeff: 0.5837374233313665
# Average most recent path length: 4.040058930345702
#
#
# Average most recent Z-score: 1.169452950373459
# Average most recent stat-score: 0.3626936788701494
# Average most recent p-value: 0.17244837533443355
# Average most recent clustering coeff: 0.5777392911401528
# Average most recent path length: 4.136293555349984
#
#
# Iters: 200
# Average most recent Z-score: 0.9493238919447311
# Average most recent stat-score: 0.29705139631610217
# Average most recent p-value: 0.37889065765090496
# Average most recent clustering coeff: 0.588179907915194
# Average most recent path length: 4.020056874635968
#
#
# Average most recent Z-score: 1.0180951158229343
# Average most recent stat-score: 0.3192163228927935
# Average most recent p-value: 0.27367612357401466
# Average most recent clustering coeff: 0.5872549248565418
# Average most recent path length: 4.136601911810053
#
#
# Iters: 210
# Average most recent Z-score: 0.8942877709380507
# Average most recent stat-score: 0.2786096256684492
# Average most recent p-value: 0.41755453079674315
# Average most recent clustering coeff: 0.609272803005587
# Average most recent path length: 4.022174255661767
#
#
# Average most recent Z-score: 1.2003460211320567
# Average most recent stat-score: 0.3201308495426142
# Average most recent p-value: 0.3246275904956235
# Average most recent clustering coeff: 0.6130711423563235
# Average most recent path length: 4.049953746530989
#
#
# Iters: 220
# Average most recent Z-score: 0.8361497293153085
# Average most recent stat-score: 0.2462640558615791
# Average most recent p-value: 0.5480580995616572
# Average most recent clustering coeff: 0.6167482544603822
# Average most recent path length: 4.016712920135677
#
#
# Average most recent Z-score: 1.435691664877952
# Average most recent stat-score: 0.41974691974691974
# Average most recent p-value: 0.08983165122056302
# Average most recent clustering coeff: 0.6182755707380166
# Average most recent path length: 4.072463768115942
#
#
# Iters: 230
# Average most recent Z-score: 1.0041412130678478
# Average most recent stat-score: 0.2740679799503329
# Average most recent p-value: 0.5092712495470509
# Average most recent clustering coeff: 0.6189421252278243
# Average most recent path length: 3.990132593277829
#
#
# Average most recent Z-score: 1.4513788351723813
# Average most recent stat-score: 0.33585858585858586
# Average most recent p-value: 0.2493405594515381
# Average most recent clustering coeff: 0.6145647779288611
# Average most recent path length: 4.043478260869565
#
#
# Iters: 240
# Average most recent Z-score: 1.0255707213641063
# Average most recent stat-score: 0.32466444231150116
# Average most recent p-value: 0.3632609364746515
# Average most recent clustering coeff: 0.6130412637147554
# Average most recent path length: 3.9515880357693494
#
#
# Average most recent Z-score: 1.1191395064936964
# Average most recent stat-score: 0.29800591565297446
# Average most recent p-value: 0.3845532695040861
# Average most recent clustering coeff: 0.6138542392559715
# Average most recent path length: 4.005242059821153
#
#
# Iters: 250
# Average most recent Z-score: 0.8308223294818918
# Average most recent stat-score: 0.2543527379053695
# Average most recent p-value: 0.49280830129301495
# Average most recent clustering coeff: 0.6121227741861038
# Average most recent path length: 3.9512796793092817
#
#
# Average most recent Z-score: 1.579747953227607
# Average most recent stat-score: 0.41904761904761906
# Average most recent p-value: 0.15700309022455114
# Average most recent clustering coeff: 0.6129772246226309
# Average most recent path length: 4.035769349367869
#
#
# Iters: 260
# Average most recent Z-score: 0.6726177184894365
# Average most recent stat-score: 0.24343434343434345
# Average most recent p-value: 0.5317795471032042
# Average most recent clustering coeff: 0.6170836712895976
# Average most recent path length: 3.9145852605612093
#
#
# Average most recent Z-score: 1.1595753204095889
# Average most recent stat-score: 0.2825311942959002
# Average most recent p-value: 0.5109912795605828
# Average most recent clustering coeff: 0.6128031271552206
# Average most recent path length: 4.012025901942645
#
#
# Iters: 270
# Average most recent Z-score: 0.5768596900778882
# Average most recent stat-score: 0.21039562289562289
# Average most recent p-value: 0.6785347746689099
# Average most recent clustering coeff: 0.6134963920150284
# Average most recent path length: 3.938945420906568
#
#
# Average most recent Z-score: 1.099281447076666
# Average most recent stat-score: 0.33880471380471383
# Average most recent p-value: 0.2782232966070814
# Average most recent clustering coeff: 0.6178126857091649
# Average most recent path length: 3.9491211840888063
#
#
# Iters: 280
# Average most recent Z-score: 0.6371663454130608
# Average most recent stat-score: 0.2545454545454546
# Average most recent p-value: 0.5784040292042615
# Average most recent clustering coeff: 0.6162868732957786
# Average most recent path length: 3.92722787542399
#
#
# Average most recent Z-score: 1.1967618296684248
# Average most recent stat-score: 0.3359180035650624
# Average most recent p-value: 0.3941218686785488
# Average most recent clustering coeff: 0.6196917025685921
# Average most recent path length: 3.9719395621338265
#
#
# Iters: 290
# Average most recent Z-score: 0.8687761852304253
# Average most recent stat-score: 0.23685064935064934
# Average most recent p-value: 0.5925173547708265
# Average most recent clustering coeff: 0.6185080062135422
# Average most recent path length: 3.9401788467468393
#
#
# Average most recent Z-score: 1.2606183994084392
# Average most recent stat-score: 0.3234913234913235
# Average most recent p-value: 0.3828690334836588
# Average most recent clustering coeff: 0.6184673675449618
# Average most recent path length: 3.938945420906568
#
#
# Iters: 300
# Average most recent Z-score: 0.5992406667320695
# Average most recent stat-score: 0.25613275613275616
# Average most recent p-value: 0.47117753790924977
# Average most recent clustering coeff: 0.6218657828810521
# Average most recent path length: 3.9167437557816833
#
#
# Average most recent Z-score: 1.3389240985828266
# Average most recent stat-score: 0.3334704511175099
# Average most recent p-value: 0.31126944325475964
# Average most recent clustering coeff: 0.6255934724221265
# Average most recent path length: 3.9398704902867716
#
#
# Iters: 310
# Average most recent Z-score: 0.5310608220336608
# Average most recent stat-score: 0.24918831168831168
# Average most recent p-value: 0.501032958144326
# Average most recent clustering coeff: 0.6220158465443991
# Average most recent path length: 3.9327782917052114
#
#
# Average most recent Z-score: 1.3506122709337471
# Average most recent stat-score: 0.3334704511175099
# Average most recent p-value: 0.31126944325475964
# Average most recent clustering coeff: 0.6246516448521003
# Average most recent path length: 3.948812827628739
#
#
# Iters: 320
# Average most recent Z-score: 0.6061878789375842
# Average most recent stat-score: 0.2555258467023173
# Average most recent p-value: 0.48165129831718917
# Average most recent clustering coeff: 0.6219021077132819
# Average most recent path length: 3.8991674375578165
#
#
# Average most recent Z-score: 1.203216904930158
# Average most recent stat-score: 0.302584670231729
# Average most recent p-value: 0.3440281695032472
# Average most recent clustering coeff: 0.6298194909594238
# Average most recent path length: 3.881899475794018
#
#
# Iters: 330
# Average most recent Z-score: 0.6643679229275147
# Average most recent stat-score: 0.2444147355912062
# Average most recent p-value: 0.541769173729716
# Average most recent clustering coeff: 0.6213585295987052
# Average most recent path length: 3.876349059512797
#
#
# Average most recent Z-score: 1.1480780253859264
# Average most recent stat-score: 0.3063973063973064
# Average most recent p-value: 0.4213124881257812
# Average most recent clustering coeff: 0.6322458137123584
# Average most recent path length: 3.8967005858772743
#
#
# Iters: 340
# Average most recent Z-score: 0.6330937327486807
# Average most recent stat-score: 0.23714349376114083
# Average most recent p-value: 0.5570882877814204
# Average most recent clustering coeff: 0.6226694231780024
# Average most recent path length: 3.8482886216466237
#
#
# Average most recent Z-score: 1.294140379991337
# Average most recent stat-score: 0.3622895622895623
# Average most recent p-value: 0.25466507555703893
# Average most recent clustering coeff: 0.6336568653112055
# Average most recent path length: 3.900709219858156
#
#
# Iters: 350
# Average most recent Z-score: 0.7188787504994595
# Average most recent stat-score: 0.23966450216450216
# Average most recent p-value: 0.5315368706356056
# Average most recent clustering coeff: 0.6260645594132005
# Average most recent path length: 3.8322540857230956
#
#
# Average most recent Z-score: 1.0405049295833904
# Average most recent stat-score: 0.296943115364168
# Average most recent p-value: 0.40807652312757076
# Average most recent clustering coeff: 0.6369711912747845
# Average most recent path length: 3.91150169596053
#
#
# Iters: 360
# Average most recent Z-score: 0.8226334738051936
# Average most recent stat-score: 0.25965537730243615
# Average most recent p-value: 0.456517685727791
# Average most recent clustering coeff: 0.6308842886255421
# Average most recent path length: 3.8513721862473016
#
#
# Average most recent Z-score: 1.1781202988060577
# Average most recent stat-score: 0.34006734006734
# Average most recent p-value: 0.3214246130888754
# Average most recent clustering coeff: 0.638228890188603
# Average most recent path length: 3.9256860931236512
#
#
# Iters: 370
# Average most recent Z-score: 0.7840400186522061
# Average most recent stat-score: 0.24961802902979377
# Average most recent p-value: 0.5283772482475769
# Average most recent clustering coeff: 0.6364127411966489
# Average most recent path length: 3.8304039469626887
#
#
# Average most recent Z-score: 1.120557355321005
# Average most recent stat-score: 0.3028198653198653
# Average most recent p-value: 0.38945050385102603
# Average most recent clustering coeff: 0.6371977008669711
# Average most recent path length: 3.9370952821461613
#
#
# Iters: 380
# Average most recent Z-score: 0.7182070508509898
# Average most recent stat-score: 0.23966450216450216
# Average most recent p-value: 0.5315368706356056
# Average most recent clustering coeff: 0.638114926992024
# Average most recent path length: 3.798026518655566
#
#
# Average most recent Z-score: 1.307533903851559
# Average most recent stat-score: 0.3600288600288601
# Average most recent p-value: 0.19898040184222943
# Average most recent clustering coeff: 0.639834192608451
# Average most recent path length: 3.9472710453283995
#
#
# Iters: 390
# Average most recent Z-score: 0.584586030407603
# Average most recent stat-score: 0.20957190957190955
# Average most recent p-value: 0.6688493628871929
# Average most recent clustering coeff: 0.6410845084275111
# Average most recent path length: 3.7918593894542085
#
#
# Average most recent Z-score: 1.3330265009523663
# Average most recent stat-score: 0.33116883116883117
# Average most recent p-value: 0.39407476465366464
# Average most recent clustering coeff: 0.6424522225167534
# Average most recent path length: 3.9093432007400555
#
#
# Iters: 400
# Average most recent Z-score: 0.6308407575740703
# Average most recent stat-score: 0.2522594364699628
# Average most recent p-value: 0.4776791478126734
# Average most recent clustering coeff: 0.6435696192285256
# Average most recent path length: 3.7798334875115636
#
#
# Average most recent Z-score: 1.1712299396651389
# Average most recent stat-score: 0.30976430976430974
# Average most recent p-value: 0.40370729791914967
# Average most recent clustering coeff: 0.6457672921472115
# Average most recent path length: 3.871106999691643
#
#
# Iters: 410
# Average most recent Z-score: 0.4819852558748135
# Average most recent stat-score: 0.17748917748917747
# Average most recent p-value: 0.7512162748634589
# Average most recent clustering coeff: 0.6577508575659105
# Average most recent path length: 3.776441566450817
#
#
# Average most recent Z-score: 1.0566872502343652
# Average most recent stat-score: 0.3004422048539696
# Average most recent p-value: 0.3424812956340571
# Average most recent clustering coeff: 0.6550564715246358
# Average most recent path length: 3.8473635522664202
#
#
# Iters: 420
# Average most recent Z-score: 0.500815501878454
# Average most recent stat-score: 0.2263917369180527
# Average most recent p-value: 0.5962699933199727
# Average most recent clustering coeff: 0.6667258428306821
# Average most recent path length: 3.769349367869257
#
#
# Average most recent Z-score: 1.0920767973551528
# Average most recent stat-score: 0.31663067324832034
# Average most recent p-value: 0.42099369282630467
# Average most recent clustering coeff: 0.6595577991857609
# Average most recent path length: 3.8556891766882515
#
#
# Iters: 430
# Average most recent Z-score: 0.5706931871599402
# Average most recent stat-score: 0.21916533758639023
# Average most recent p-value: 0.6467978790908265
# Average most recent clustering coeff: 0.6687449848883799
# Average most recent path length: 3.8063521430773974
#
#
# Average most recent Z-score: 0.918542585985521
# Average most recent stat-score: 0.3118439294909883
# Average most recent p-value: 0.3682180970116786
# Average most recent clustering coeff: 0.659773997814847
# Average most recent path length: 3.896392229417206
#
#
# Iters: 440
# Average most recent Z-score: 0.4562769823064356
# Average most recent stat-score: 0.17331681476418317
# Average most recent p-value: 0.7890890121166496
# Average most recent clustering coeff: 0.6707642720818606
# Average most recent path length: 3.8202281837804506
#
#
# Average most recent Z-score: 1.0180710104479134
# Average most recent stat-score: 0.3121867239514298
# Average most recent p-value: 0.4299629172571981
# Average most recent clustering coeff: 0.6642879210758866
# Average most recent path length: 3.9207523897625656
#
#
# Iters: 450
# Average most recent Z-score: 0.3990700520882134
# Average most recent stat-score: 0.18807720057720057
# Average most recent p-value: 0.7284253244558222
# Average most recent clustering coeff: 0.6741242217154312
# Average most recent path length: 3.830712303422757
#
#
# Average most recent Z-score: 1.0248470501481084
# Average most recent stat-score: 0.3334780687721864
# Average most recent p-value: 0.32100210223802855
# Average most recent clustering coeff: 0.6641011097952808
# Average most recent path length: 3.900709219858156
#
#
# Iters: 460
# Average most recent Z-score: 0.4041200688500679
# Average most recent stat-score: 0.20625901875901875
# Average most recent p-value: 0.6988460912365126
# Average most recent clustering coeff: 0.6721335116177203
# Average most recent path length: 3.8233117483811285
#
#
# Average most recent Z-score: 1.2254806232688547
# Average most recent stat-score: 0.41488413547237074
# Average most recent p-value: 0.26811830572497936
# Average most recent clustering coeff: 0.6646189512181507
# Average most recent path length: 3.869873573851372
#
#
# Iters: 470
# Average most recent Z-score: 0.6878121215514574
# Average most recent stat-score: 0.20772005772005772
# Average most recent p-value: 0.7021405889274491
# Average most recent clustering coeff: 0.671669500937316
# Average most recent path length: 3.843354918285538
#
#
# Average most recent Z-score: 0.9450888279406447
# Average most recent stat-score: 0.2766062626743741
# Average most recent p-value: 0.49124193664692717
# Average most recent clustering coeff: 0.6623459334868026
# Average most recent path length: 3.8556891766882515
#
#
# Iters: 480
# Average most recent Z-score: 0.5805145486625776
# Average most recent stat-score: 0.20973470973470976
# Average most recent p-value: 0.7088119455706644
# Average most recent clustering coeff: 0.6726837245369349
# Average most recent path length: 3.8744989207523894
#
#
# Average most recent Z-score: 0.9822224863550001
# Average most recent stat-score: 0.3218551314526547
# Average most recent p-value: 0.3902694369669583
# Average most recent clustering coeff: 0.6625630605096108
# Average most recent path length: 3.8522972556275055
#
#
# Iters: 490
# Average most recent Z-score: 0.6626945459275946
# Average most recent stat-score: 0.2508417508417508
# Average most recent p-value: 0.5737245622235991
# Average most recent clustering coeff: 0.6707306144050592
# Average most recent path length: 3.848905334566759
#
#
# Average most recent Z-score: 0.7969997057333603
# Average most recent stat-score: 0.23636110478215744
# Average most recent p-value: 0.5889349577114595
# Average most recent clustering coeff: 0.6638383373017633
# Average most recent path length: 3.837496145544249
#
#
# Iters: 500
# Average most recent Z-score: 0.5766784128936472
# Average most recent stat-score: 0.1659071922229817
# Average most recent p-value: 0.8532093420137216
# Average most recent clustering coeff: 0.6716062544481839
# Average most recent path length: 3.863706444650015
#
#
# Average most recent Z-score: 0.8580478071105088
# Average most recent stat-score: 0.24420007237344699
# Average most recent p-value: 0.5404450788261362
# Average most recent clustering coeff: 0.6610135100982887
# Average most recent path length: 3.866790009250694
#
#
# Iters: 510
# Average most recent Z-score: 0.5797460222822287
# Average most recent stat-score: 0.1659071922229817
# Average most recent p-value: 0.8532093420137216
# Average most recent clustering coeff: 0.6693485211190132
# Average most recent path length: 3.879432624113475
#
#
# Average most recent Z-score: 0.7776655919711807
# Average most recent stat-score: 0.268958939237577
# Average most recent p-value: 0.4036244589124305
# Average most recent clustering coeff: 0.6604944034770271
# Average most recent path length: 3.889916743755782
#
#
# Iters: 520
# Average most recent Z-score: 0.4184296279772329
# Average most recent stat-score: 0.13701298701298703
# Average most recent p-value: 0.9174561908658756
# Average most recent clustering coeff: 0.6701013936703042
# Average most recent path length: 3.877890841813136
#
#
# Average most recent Z-score: 0.89772077536885
# Average most recent stat-score: 0.32086976204623263
# Average most recent p-value: 0.23869388251650658
# Average most recent clustering coeff: 0.6617837202207509
# Average most recent path length: 3.889608387295714
#
#
# Iters: 530
# Average most recent Z-score: 0.589437251931847
# Average most recent stat-score: 0.20235690235690232
# Average most recent p-value: 0.6779593842765249
# Average most recent clustering coeff: 0.6685293267837688
# Average most recent path length: 3.8899167437557813
#
#
# Average most recent Z-score: 1.001385358671234
# Average most recent stat-score: 0.33351370851370854
# Average most recent p-value: 0.21656324166149177
# Average most recent clustering coeff: 0.6643409183571706
# Average most recent path length: 3.8979340117175454
#
#
# Iters: 540
# Average most recent Z-score: 0.7374432812914501
# Average most recent stat-score: 0.19446343130553656
# Average most recent p-value: 0.7733533380711853
# Average most recent clustering coeff: 0.6711402733605816
# Average most recent path length: 3.873573851372187
#
#
# Average most recent Z-score: 0.9988111945776547
# Average most recent stat-score: 0.3326967150496562
# Average most recent p-value: 0.21144709701412548
# Average most recent clustering coeff: 0.6637979441306562
# Average most recent path length: 3.928769657724329
#
#
# Iters: 550
# Average most recent Z-score: 0.6464922758095812
# Average most recent stat-score: 0.19930887825624666
# Average most recent p-value: 0.7419456274044899
# Average most recent clustering coeff: 0.671686949578108
# Average most recent path length: 3.9133518347209377
#
#
# Average most recent Z-score: 0.8576118049909787
# Average most recent stat-score: 0.2987126163596752
# Average most recent p-value: 0.314741003321684
# Average most recent clustering coeff: 0.660910385409268
# Average most recent path length: 3.902559358618563
#
#
# Iters: 560
# Average most recent Z-score: 0.6338934440294559
# Average most recent stat-score: 0.21916533758639023
# Average most recent p-value: 0.6541056771596085
# Average most recent clustering coeff: 0.6699130056851698
# Average most recent path length: 3.9555966697502316
#
#
# Average most recent Z-score: 0.964708776577622
# Average most recent stat-score: 0.31956823133293716
# Average most recent p-value: 0.3437019165334028
# Average most recent clustering coeff: 0.6598028801590653
# Average most recent path length: 3.943262411347517
#
#
# Iters: 570
# Average most recent Z-score: 0.46910362653519905
# Average most recent stat-score: 0.20454545454545456
# Average most recent p-value: 0.7167822156453055
# Average most recent clustering coeff: 0.6692681398876447
# Average most recent path length: 3.968239284613013
#
#
# Average most recent Z-score: 0.9200422523174852
# Average most recent stat-score: 0.29200336700336704
# Average most recent p-value: 0.35176693680878457
# Average most recent clustering coeff: 0.6597927695212387
# Average most recent path length: 3.9087264878199197
#
#
# Iters: 580
# Average most recent Z-score: 0.5284166565607237
# Average most recent stat-score: 0.26397527910685803
# Average most recent p-value: 0.4119229931548771
# Average most recent clustering coeff: 0.6709163785839501
# Average most recent path length: 3.983348751156337
#
#
# Average most recent Z-score: 0.9159963936873893
# Average most recent stat-score: 0.29821746880570416
# Average most recent p-value: 0.32913866979060674
# Average most recent clustering coeff: 0.6588151402693364
# Average most recent path length: 3.9312365094048722
#
#
# Iters: 590
# Average most recent Z-score: 0.47272767354954376
# Average most recent stat-score: 0.18329580636082185
# Average most recent p-value: 0.8060857123394913
# Average most recent clustering coeff: 0.6682396127470919
# Average most recent path length: 4.013259327782918
#
#
# Average most recent Z-score: 1.0571848870936338
# Average most recent stat-score: 0.34840527119938886
# Average most recent p-value: 0.20340923852753756
# Average most recent clustering coeff: 0.6553121521437548
# Average most recent path length: 3.9121184088806658
#
#
# Iters: 600
# Average most recent Z-score: 0.5194230884764205
# Average most recent stat-score: 0.1733277042874566
# Average most recent p-value: 0.8585992511593478
# Average most recent clustering coeff: 0.6672556386953011
# Average most recent path length: 3.9411039161270427
#
#
# Average most recent Z-score: 0.989854581584623
# Average most recent stat-score: 0.39369889369889366
# Average most recent p-value: 0.10070248731068
# Average most recent clustering coeff: 0.6556630568761749
# Average most recent path length: 3.924144310823312
#
#
# Iters: 610
# Average most recent Z-score: 0.6552600644780747
# Average most recent stat-score: 0.1884635832004253
# Average most recent p-value: 0.7464585436392243
# Average most recent clustering coeff: 0.6676977863611165
# Average most recent path length: 3.9435707678075858
#
#
# Average most recent Z-score: 1.005172055331413
# Average most recent stat-score: 0.33689839572192515
# Average most recent p-value: 0.2644187063478255
# Average most recent clustering coeff: 0.6574881699777165
# Average most recent path length: 3.933086648165279
#
#
# Iters: 620
# Average most recent Z-score: 0.8049384247375243
# Average most recent stat-score: 0.27868914711019976
# Average most recent p-value: 0.4429119114967824
# Average most recent clustering coeff: 0.6726873778471835
# Average most recent path length: 3.9759481961147087
#
#
# Average most recent Z-score: 0.8392963634736604
# Average most recent stat-score: 0.2815285204991087
# Average most recent p-value: 0.3669001861482422
# Average most recent clustering coeff: 0.6606673388999253
# Average most recent path length: 3.9438791242676534
#
#
# Iters: 630
# Average most recent Z-score: 0.5984779275521527
# Average most recent stat-score: 0.23817340067340065
# Average most recent p-value: 0.5541265950476811
# Average most recent clustering coeff: 0.676593762634769
# Average most recent path length: 3.9522047486894842
#
#
# Average most recent Z-score: 0.697555027827795
# Average most recent stat-score: 0.21826104179045358
# Average most recent p-value: 0.6465175524476944
# Average most recent clustering coeff: 0.6634971725790751
# Average most recent path length: 3.9574468085106385
#
#
# Iters: 640
# Average most recent Z-score: 0.7048378441229165
# Average most recent stat-score: 0.22692677549488693
# Average most recent p-value: 0.6101499444745928
# Average most recent clustering coeff: 0.6773566518801538
# Average most recent path length: 3.9034844279987673
#
#
# Average most recent Z-score: 0.711207520563384
# Average most recent stat-score: 0.2647306397306397
# Average most recent p-value: 0.4486037077742524
# Average most recent clustering coeff: 0.6647445262662847
# Average most recent path length: 3.9599136601911815
#
#
# Iters: 650
# Average most recent Z-score: 0.710533327252754
# Average most recent stat-score: 0.2422647527910686
# Average most recent p-value: 0.5379829693598079
# Average most recent clustering coeff: 0.6751824926788922
# Average most recent path length: 3.9312365094048722
#
#
# Average most recent Z-score: 0.8420647854980149
# Average most recent stat-score: 0.277619330560507
# Average most recent p-value: 0.4228616456338128
# Average most recent clustering coeff: 0.6624177406542522
# Average most recent path length: 3.9700894233734196
#
#
# Iters: 660
# Average most recent Z-score: 0.6457924601225823
# Average most recent stat-score: 0.28232323232323236
# Average most recent p-value: 0.388752730463593
# Average most recent clustering coeff: 0.6774055986131157
# Average most recent path length: 3.9284613012642615
#
#
# Average most recent Z-score: 0.9373692810602399
# Average most recent stat-score: 0.3231729055258467
# Average most recent p-value: 0.2215924522857862
# Average most recent clustering coeff: 0.6630980677479567
# Average most recent path length: 4.006783842121492
#
#
# Iters: 670
# Average most recent Z-score: 0.6441709938657055
# Average most recent stat-score: 0.28086124401913876
# Average most recent p-value: 0.3794924701683661
# Average most recent clustering coeff: 0.6755273108770782
# Average most recent path length: 3.940795559666975
#
#
# Average most recent Z-score: 0.9286689672123335
# Average most recent stat-score: 0.3374331550802139
# Average most recent p-value: 0.2124282376742104
# Average most recent clustering coeff: 0.6647650691679373
# Average most recent path length: 4.018809744064138
#
#
# Iters: 680
# Average most recent Z-score: 0.6305808970978194
# Average most recent stat-score: 0.26980329611908566
# Average most recent p-value: 0.3891894248539752
# Average most recent clustering coeff: 0.6754100631505119
# Average most recent path length: 3.947579401788467
#
#
# Average most recent Z-score: 0.9112234732577225
# Average most recent stat-score: 0.35704099821746876
# Average most recent p-value: 0.14326808226940138
# Average most recent clustering coeff: 0.664504473142686
# Average most recent path length: 4.006167129201357
#
#
# Iters: 690
# Average most recent Z-score: 0.5831159600399675
# Average most recent stat-score: 0.19951899951899954
# Average most recent p-value: 0.7279495931069743
# Average most recent clustering coeff: 0.6773450251347009
# Average most recent path length: 3.960838729571385
#
#
# Average most recent Z-score: 0.8839747170903923
# Average most recent stat-score: 0.2518716577540107
# Average most recent p-value: 0.548732196789684
# Average most recent clustering coeff: 0.6614305701260582
# Average most recent path length: 4.010175763182239
#
#
# Iters: 700
# Average most recent Z-score: 0.6049719677520432
# Average most recent stat-score: 0.25262145262145264
# Average most recent p-value: 0.5176471002144862
# Average most recent clustering coeff: 0.6774048896034685
# Average most recent path length: 3.9568300955905027
#
#
# Average most recent Z-score: 0.8378258686791705
# Average most recent stat-score: 0.2546444840562488
# Average most recent p-value: 0.5286801886020832
# Average most recent clustering coeff: 0.6624405988754377
# Average most recent path length: 4.035460992907802
#
#
# Iters: 710
# Average most recent Z-score: 0.508050140674292
# Average most recent stat-score: 0.20216450216450213
# Average most recent p-value: 0.6926457996676681
# Average most recent clustering coeff: 0.6769976348030698
# Average most recent path length: 4.018809744064138
#
#
# Average most recent Z-score: 0.9273836423406011
# Average most recent stat-score: 0.3064963359081006
# Average most recent p-value: 0.39519699288363225
# Average most recent clustering coeff: 0.6644404563984824
# Average most recent path length: 4.047178538390379
#
#
# Iters: 720
# Average most recent Z-score: 0.4965569680027791
# Average most recent stat-score: 0.20714285714285716
# Average most recent p-value: 0.68334689946672
# Average most recent clustering coeff: 0.6755597061257897
# Average most recent path length: 4.046253469010176
#
#
# Average most recent Z-score: 0.9684670862709769
# Average most recent stat-score: 0.2936083524318818
# Average most recent p-value: 0.33701705226587775
# Average most recent clustering coeff: 0.6658766716460389
# Average most recent path length: 4.077397471477028
#
#
# Iters: 730
# Average most recent Z-score: 0.4682848312765519
# Average most recent stat-score: 0.17427526034337182
# Average most recent p-value: 0.7950208543136973
# Average most recent clustering coeff: 0.6774613922384046
# Average most recent path length: 4.059512796793093
#
#
# Average most recent Z-score: 0.9915057229313589
# Average most recent stat-score: 0.32149223325693915
# Average most recent p-value: 0.4344967884844422
# Average most recent clustering coeff: 0.6665733465483378
# Average most recent path length: 4.071847055195806
#
#
# Iters: 740
# Average most recent Z-score: 0.41573855337394794
# Average most recent stat-score: 0.17076648841354725
# Average most recent p-value: 0.8069835971166218
# Average most recent clustering coeff: 0.6788302355326087
# Average most recent path length: 4.045020043169905
#
#
# Average most recent Z-score: 0.9146867325403901
# Average most recent stat-score: 0.31592394533571005
# Average most recent p-value: 0.4038805824675356
# Average most recent clustering coeff: 0.667112219995647
# Average most recent path length: 4.09559050262103
#
#
# Iters: 750
# Average most recent Z-score: 0.5357695325708852
# Average most recent stat-score: 0.1970693779904306
# Average most recent p-value: 0.7474853576275424
# Average most recent clustering coeff: 0.6846315940613819
# Average most recent path length: 4.0459451125501085
#
#
# Average most recent Z-score: 0.9877489313953429
# Average most recent stat-score: 0.32149223325693915
# Average most recent p-value: 0.4344967884844422
# Average most recent clustering coeff: 0.6688693565353137
# Average most recent path length: 4.134751773049646
#
#
# Iters: 760
# Average most recent Z-score: 0.6699835596560085
# Average most recent stat-score: 0.1878787878787879
# Average most recent p-value: 0.7573065390920924
# Average most recent clustering coeff: 0.6866897627158366
# Average most recent path length: 4.0684551341350605
#
#
# Average most recent Z-score: 0.7809285392501346
# Average most recent stat-score: 0.2575820120711762
# Average most recent p-value: 0.5169501518028157
# Average most recent clustering coeff: 0.669954139032998
# Average most recent path length: 4.147394387912427
#
#
# Iters: 770
# Average most recent Z-score: 0.632185167261696
# Average most recent stat-score: 0.22544492544492545
# Average most recent p-value: 0.6505856762948447
# Average most recent clustering coeff: 0.689043826519069
# Average most recent path length: 4.098674067221708
#
#
# Average most recent Z-score: 0.758093306480128
# Average most recent stat-score: 0.2516587443058031
# Average most recent p-value: 0.5211137668908894
# Average most recent clustering coeff: 0.67267788977583
# Average most recent path length: 4.183163737280296
#
#
# Iters: 780
# Average most recent Z-score: 0.3946502590797092
# Average most recent stat-score: 0.22258185570879072
# Average most recent p-value: 0.6643766838912786
# Average most recent clustering coeff: 0.6900935776346891
# Average most recent path length: 4.1128584643848285
#
#
# Average most recent Z-score: 0.8308006400979706
# Average most recent stat-score: 0.2599920776391365
# Average most recent p-value: 0.5017012927301295
# Average most recent clustering coeff: 0.6746543724600289
# Average most recent path length: 4.192722787542398
#
#
# Iters: 790
# Average most recent Z-score: 0.3406449925989972
# Average most recent stat-score: 0.17522281639928697
# Average most recent p-value: 0.7486704780087409
# Average most recent clustering coeff: 0.6919421478048898
# Average most recent path length: 4.145852605612087
#
#
# Average most recent Z-score: 0.7742400087847234
# Average most recent stat-score: 0.23463804713804715
# Average most recent p-value: 0.5886692799006941
# Average most recent clustering coeff: 0.6761199471353282
# Average most recent path length: 4.175146469318532
#
#
# Iters: 800
# Average most recent Z-score: 0.25393274410025096
# Average most recent stat-score: 0.21094208434361886
# Average most recent p-value: 0.665506179981494
# Average most recent clustering coeff: 0.6933320219075393
# Average most recent path length: 4.164970706136294
#
#
# Average most recent Z-score: 0.7206795991373606
# Average most recent stat-score: 0.22973608635373344
# Average most recent p-value: 0.6018772428050362
# Average most recent clustering coeff: 0.6772523575160837
# Average most recent path length: 4.176996608078939
#
#
# Iters: 810
# Average most recent Z-score: 0.5062729487078311
# Average most recent stat-score: 0.19907407407407407
# Average most recent p-value: 0.6885529862948415
# Average most recent clustering coeff: 0.6952966067740544
# Average most recent path length: 4.203206907184705
#
#
# Average most recent Z-score: 0.673663235577635
# Average most recent stat-score: 0.24321647851059613
# Average most recent p-value: 0.5209124174223968
# Average most recent clustering coeff: 0.6768189237436179
# Average most recent path length: 4.217699660807894
#
#
# Iters: 820
# Average most recent Z-score: 0.4468735172653135
# Average most recent stat-score: 0.16145382395382393
# Average most recent p-value: 0.7895525659559098
# Average most recent clustering coeff: 0.6999699221300747
# Average most recent path length: 4.261486278137528
#
#
# Average most recent Z-score: 0.8671716314264529
# Average most recent stat-score: 0.2609180035650624
# Average most recent p-value: 0.461003758245455
# Average most recent clustering coeff: 0.6790944477703712
# Average most recent path length: 4.254702436016035
#
#
# Iters: 830
# Average most recent Z-score: 0.42904387186090776
# Average most recent stat-score: 0.17460317460317462
# Average most recent p-value: 0.7658102360520239
# Average most recent clustering coeff: 0.7028630294652466
# Average most recent path length: 4.316373728029602
#
#
# Average most recent Z-score: 0.752303318755536
# Average most recent stat-score: 0.28978510596157653
# Average most recent p-value: 0.34480431711039916
# Average most recent clustering coeff: 0.6812010736796196
# Average most recent path length: 4.285846438482886
#
#
# Iters: 840
# Average most recent Z-score: 0.7109145948631702
# Average most recent stat-score: 0.2204032809295967
# Average most recent p-value: 0.6365921380692249
# Average most recent clustering coeff: 0.705284522721831
# Average most recent path length: 4.304964539007092
#
#
# Average most recent Z-score: 0.8388620445721168
# Average most recent stat-score: 0.25628837393543275
# Average most recent p-value: 0.4727187021143428
# Average most recent clustering coeff: 0.6809690504265408
# Average most recent path length: 4.321924144310823
#
#
# Iters: 850
# Average most recent Z-score: 0.4945630849083758
# Average most recent stat-score: 0.20850421508316244
# Average most recent p-value: 0.6467763299189232
# Average most recent clustering coeff: 0.7054250364015844
# Average most recent path length: 4.341967314215233
#
#
# Average most recent Z-score: 0.6045829324636663
# Average most recent stat-score: 0.3109051036682616
# Average most recent p-value: 0.26865804383456005
# Average most recent clustering coeff: 0.6851411653021194
# Average most recent path length: 4.375886524822695
#
#
# Iters: 860
# Average most recent Z-score: 0.3978217031397353
# Average most recent stat-score: 0.17500000000000002
# Average most recent p-value: 0.7364934354884912
# Average most recent clustering coeff: 0.7083163716766935
# Average most recent path length: 4.4036386062288
#
#
# Average most recent Z-score: 0.5096212870926952
# Average most recent stat-score: 0.24830067593225488
# Average most recent p-value: 0.5051617791060689
# Average most recent clustering coeff: 0.6865810497976138
# Average most recent path length: 4.396854764107308
#
#
# Iters: 870
# Average most recent Z-score: 0.37486601221858346
# Average most recent stat-score: 0.18274340039045922
# Average most recent p-value: 0.7893353659152104
# Average most recent clustering coeff: 0.7112469033752191
# Average most recent path length: 4.442799876657417
#
#
# Average most recent Z-score: 0.666127013259958
# Average most recent stat-score: 0.2442736185383244
# Average most recent p-value: 0.5244871481083498
# Average most recent clustering coeff: 0.6845452648720837
# Average most recent path length: 4.443108233117484
#
#
# Iters: 880
# Average most recent Z-score: 0.5116962798291844
# Average most recent stat-score: 0.23900660742766008
# Average most recent p-value: 0.6393908501103942
# Average most recent clustering coeff: 0.7148391401978436
# Average most recent path length: 4.465926611162504
#
#
# Average most recent Z-score: 0.7870106658261866
# Average most recent stat-score: 0.27306397306397306
# Average most recent p-value: 0.4291912336134926
# Average most recent clustering coeff: 0.6893992295437662
# Average most recent path length: 4.480419364785693
#
#
# Iters: 890
# Average most recent Z-score: 0.3647102396134065
# Average most recent stat-score: 0.20364357864357863
# Average most recent p-value: 0.7151495591956101
# Average most recent clustering coeff: 0.7147831758017046
# Average most recent path length: 4.480419364785692
#
#
# Average most recent Z-score: 0.7200247112613227
# Average most recent stat-score: 0.2338118022328549
# Average most recent p-value: 0.6240088428624988
# Average most recent clustering coeff: 0.6896913583210348
# Average most recent path length: 4.517113783533765
#
#
# Iters: 900
# Average most recent Z-score: 0.4392495184335316
# Average most recent stat-score: 0.19682539682539682
# Average most recent p-value: 0.6990506985201875
# Average most recent clustering coeff: 0.7157482680525998
# Average most recent path length: 4.548874498920752
#
#
# Average most recent Z-score: 0.7083273491601526
# Average most recent stat-score: 0.26046176046176045
# Average most recent p-value: 0.6043442677002262
# Average most recent clustering coeff: 0.6902455315847048
# Average most recent path length: 4.552883132901634
#
#
# Iters: 910
# Average most recent Z-score: 0.375712235689247
# Average most recent stat-score: 0.16687038451744332
# Average most recent p-value: 0.8075990525075585
# Average most recent clustering coeff: 0.7175659796381795
# Average most recent path length: 4.596053037311132
#
#
# Average most recent Z-score: 0.7666028544668527
# Average most recent stat-score: 0.2558922558922559
# Average most recent p-value: 0.4828695478254983
# Average most recent clustering coeff: 0.6953353973379137
# Average most recent path length: 4.592661116250386
#
#
# Iters: 920
# Average most recent Z-score: 0.3970956409823767
# Average most recent stat-score: 0.1693181818181818
# Average most recent p-value: 0.8103823056093069
# Average most recent clustering coeff: 0.7181821582067772
# Average most recent path length: 4.632130743139069
#
#
# Average most recent Z-score: 0.6013121875735541
# Average most recent stat-score: 0.1843013468013468
# Average most recent p-value: 0.790575860614588
# Average most recent clustering coeff: 0.696575470078744
# Average most recent path length: 4.62473018809744
#
#
# Iters: 930
# Average most recent Z-score: 0.4493016068839319
# Average most recent stat-score: 0.1976911976911977
# Average most recent p-value: 0.7359536518546088
# Average most recent clustering coeff: 0.7198419931193304
# Average most recent path length: 4.662041319765649
#
#
# Average most recent Z-score: 0.4881902772621274
# Average most recent stat-score: 0.17054296466061172
# Average most recent p-value: 0.8648420495903523
# Average most recent clustering coeff: 0.6960456390062033
# Average most recent path length: 4.661424606845514
#
#
# Iters: 940
# Average most recent Z-score: 0.3330301260614349
# Average most recent stat-score: 0.2204616036137775
# Average most recent p-value: 0.6288429986671981
# Average most recent clustering coeff: 0.7194998083494566
# Average most recent path length: 4.680542707369719
#
#
# Average most recent Z-score: 0.557329986532285
# Average most recent stat-score: 0.166157372039725
# Average most recent p-value: 0.8139862562371736
# Average most recent clustering coeff: 0.6989807769300612
# Average most recent path length: 4.709528214616096
#
#
# Iters: 950
# Average most recent Z-score: 0.3809265185090576
# Average most recent stat-score: 0.1915204678362573
# Average most recent p-value: 0.7233397325545344
# Average most recent clustering coeff: 0.7185816910351259
# Average most recent path length: 4.845513413506013
#
#
# Average most recent Z-score: 0.49504657418364917
# Average most recent stat-score: 0.20758000169764879
# Average most recent p-value: 0.6853901324725058
# Average most recent clustering coeff: 0.7019700448735026
# Average most recent path length: 4.839346284304656
#
#
# Iters: 960
# Average most recent Z-score: 0.3210769835943022
# Average most recent stat-score: 0.18988648090815274
# Average most recent p-value: 0.7029133794472809
# Average most recent clustering coeff: 0.7168875548278507
# Average most recent path length: 4.901942645698427
#
#
# Average most recent Z-score: 0.3367834924237029
# Average most recent stat-score: 0.146641857168173
# Average most recent p-value: 0.8693424532141965
# Average most recent clustering coeff: 0.7028663261608918
# Average most recent path length: 4.8714153561517115
#
#
# Iters: 970
# Average most recent Z-score: 0.3798923813790309
# Average most recent stat-score: 0.22501646903820816
# Average most recent p-value: 0.6602631162607376
# Average most recent clustering coeff: 0.7164518147032185
# Average most recent path length: 4.9990749306197975
#
#
# Average most recent Z-score: 0.32458285320325
# Average most recent stat-score: 0.12472089314194577
# Average most recent p-value: 0.9386987573658047
# Average most recent clustering coeff: 0.7033943014911616
# Average most recent path length: 5.037311131668208
#
#
# Iters: 980
# Average most recent Z-score: 0.3402616798341292
# Average most recent stat-score: 0.2263888888888889
# Average most recent p-value: 0.6581891695780439
# Average most recent clustering coeff: 0.718266509297119
# Average most recent path length: 5.098057354301573
#
#
# Average most recent Z-score: 0.24912631942460828
# Average most recent stat-score: 0.16021080368906457
# Average most recent p-value: 0.8976296296476151
# Average most recent clustering coeff: 0.7061759392229545
# Average most recent path length: 5.1085414739438795
#
#
# Iters: 990
# Average most recent Z-score: 0.34110160108897203
# Average most recent stat-score: 0.18409090909090908
# Average most recent p-value: 0.7345934756816197
# Average most recent clustering coeff: 0.7168150448005773
# Average most recent path length: 5.189330866481653
#
#
# Average most recent Z-score: 0.3504005724638193
# Average most recent stat-score: 0.1627680311890838
# Average most recent p-value: 0.8939828524381636
# Average most recent clustering coeff: 0.7077846290400963
# Average most recent path length: 5.271970397779833
#
#
# Iters: 1000
# Average most recent Z-score: 0.3960796325635429
# Average most recent stat-score: 0.20952950558213715
# Average most recent p-value: 0.6311057062259859
# Average most recent clustering coeff: 0.7176729419051887
# Average most recent path length: 5.302806043786617
#
#
# Average most recent Z-score: 0.4037675494819201
# Average most recent stat-score: 0.21944939591998416
# Average most recent p-value: 0.6425611070803922
# Average most recent clustering coeff: 0.7084229222745533
# Average most recent path length: 5.357385137218625
#
#
# Iters: 1010
# Average most recent Z-score: 0.4249419836358113
# Average most recent stat-score: 0.22846538703316197
# Average most recent p-value: 0.5165161784544364
# Average most recent clustering coeff: 0.7205372008819992
# Average most recent path length: 5.518655565834105
#
#
# Average most recent Z-score: 0.3438498691336327
# Average most recent stat-score: 0.16114316540013135
# Average most recent p-value: 0.7700392592604272
# Average most recent clustering coeff: 0.7088508390585894
# Average most recent path length: 5.451125501079248
#
#
# Iters: 1020
# Average most recent Z-score: 0.23240996178348464
# Average most recent stat-score: 0.14213145952276388
# Average most recent p-value: 0.8548342761142523
# Average most recent clustering coeff: 0.7194164264109477
# Average most recent path length: 5.298489053345667
#
#
# Average most recent Z-score: 0.3048885579490594
# Average most recent stat-score: 0.1743098413578963
# Average most recent p-value: 0.8163921844830329
# Average most recent clustering coeff: 0.7102992295906482
# Average most recent path length: 5.400246685168054
#
#
# Iters: 1030
# Average most recent Z-score: 0.15064625722832678
# Average most recent stat-score: 0.15518278018278017
# Average most recent p-value: 0.8481646492425062
# Average most recent clustering coeff: 0.7193729642720678
# Average most recent path length: 5.041011409189022
#
#
# Average most recent Z-score: 0.3070291932377424
# Average most recent stat-score: 0.15441216127714982
# Average most recent p-value: 0.8386327372662361
# Average most recent clustering coeff: 0.7116304621800218
# Average most recent path length: 5.3617021276595755
#
#
# Iters: 1040
# Average most recent Z-score: 0.14069112067242853
# Average most recent stat-score: 0.13002037372746755
# Average most recent p-value: 0.9134022364819775
# Average most recent clustering coeff: 0.7178057194698023
# Average most recent path length: 5.00709219858156
#
#
# Average most recent Z-score: 0.32314687617035825
# Average most recent stat-score: 0.16540404040404041
# Average most recent p-value: 0.8730596959845448
# Average most recent clustering coeff: 0.7134277604179152
# Average most recent path length: 5.470551958063521
#
#
# Iters: 1050
# Average most recent Z-score: 0.23088688762461437
# Average most recent stat-score: 0.15350877192982457
# Average most recent p-value: 0.8624308138028328
# Average most recent clustering coeff: 0.717137364072765
# Average most recent path length: 4.836879432624113
#
#
# Average most recent Z-score: 0.32716841929788004
# Average most recent stat-score: 0.18392255892255893
# Average most recent p-value: 0.7773175678369215
# Average most recent clustering coeff: 0.7128580374640432
# Average most recent path length: 5.628738822078323
#
#
# Iters: 1060
# Average most recent Z-score: 0.19035016993400533
# ...
# Average most recent p-value: 0.9310461853763501
# Average most recent clustering coeff: 0.712900506970819
# Average most recent path length: 4.556891766882516
#
#
# Iters: 1200
# Average most recent Z-score: 0.24714235977199328
# Average most recent stat-score: 0.1336732321387053
# Average most recent p-value: 0.9297870835457965
# Average most recent clustering coeff: 0.7275912182091716
# Average most recent path length: 4.465618254702436
#
#
# Average most recent Z-score: 0.35507678040357477
# Average most recent stat-score: 0.1158008658008658
# Average most recent p-value: 0.9183634599692786
# Average most recent clustering coeff: 0.7148812274542552
# Average most recent path length: 4.6188714153561525
#
#
# Iters: 1210
# Average most recent Z-score: 0.3755512618074542
# Average most recent stat-score: 0.19515961621224778
# Average most recent p-value: 0.7314567642697481
# Average most recent clustering coeff: 0.7264998515123874
# Average most recent path length: 4.453900709219859
#
#
# Average most recent Z-score: 0.3927798388321926
# Average most recent stat-score: 0.16687038451744332
# Average most recent p-value: 0.8075990525075585
# Average most recent clustering coeff: 0.715097861857485
# Average most recent path length: 4.662658032685784
#
#
# Iters: 1220
# Average most recent Z-score: 0.2390655968566464
# Average most recent stat-score: 0.15873015873015875
# Average most recent p-value: 0.771789918013189
# Average most recent clustering coeff: 0.7308403475664753
# Average most recent path length: 4.413506012950972
#
#
# Average most recent Z-score: 0.4334776598255547
# Average most recent stat-score: 0.21819067871699452
# Average most recent p-value: 0.6300433210614789
# Average most recent clustering coeff: 0.7151479729249656
# Average most recent path length: 4.514030218933087
#
#
# Iters: 1230
# Average most recent Z-score: 0.15091745449569208
# Average most recent stat-score: 0.13270385009515442
# Average most recent p-value: 0.948169395414364
# Average most recent clustering coeff: 0.7290563723828373
# Average most recent path length: 4.454825778600061
#
#
# Average most recent Z-score: 0.38806440425871075
# Average most recent stat-score: 0.16228703070808334
# Average most recent p-value: 0.8963468202908951
# Average most recent clustering coeff: 0.716831347322927
# Average most recent path length: 4.351218008017267
#
#
# Iters: 1240
# Average most recent Z-score: 0.20400811594070245
# Average most recent stat-score: 0.1445511010728402
# Average most recent p-value: 0.9270652081453189
# Average most recent clustering coeff: 0.7282927999659617
# Average most recent path length: 4.4708603145235895
#
#
# Average most recent Z-score: 0.37207255851016235
# Average most recent stat-score: 0.16156299840510366
# Average most recent p-value: 0.9020667646628152
# Average most recent clustering coeff: 0.719875525230221
# Average most recent path length: 4.470551958063521
#
#
# Iters: 1250
# Average most recent Z-score: 0.06380825366810551
# Average most recent stat-score: 0.16208133971291866
# Average most recent p-value: 0.7833731284980937
# Average most recent clustering coeff: 0.7304565555310218
# Average most recent path length: 4.527289546716004
#
#
# Average most recent Z-score: 0.5355317562372224
# Average most recent stat-score: 0.20409982174688057
# Average most recent p-value: 0.7059769295971505
# Average most recent clustering coeff: 0.7183422666782718
# Average most recent path length: 4.479802651865556
#
#
# Iters: 1260
# Average most recent Z-score: 0.14958672937484233
# Average most recent stat-score: 0.15780998389694043
# Average most recent p-value: 0.8514771747653921
# Average most recent clustering coeff: 0.7309906200613173
# Average most recent path length: 4.4736355226642
#
#
# Average most recent Z-score: 0.4894265159709095
# Average most recent stat-score: 0.20959595959595959
# Average most recent p-value: 0.6850118977599418
# Average most recent clustering coeff: 0.718208558555514
# Average most recent path length: 4.550107924761023
#
#
# Iters: 1270
# Average most recent Z-score: 0.28485372883255294
# Average most recent stat-score: 0.1574074074074074
# Average most recent p-value: 0.8505971198252821
# Average most recent clustering coeff: 0.7323702140810769
# Average most recent path length: 4.515263644773358
#
#
# Average most recent Z-score: 0.39917928412040354
# Average most recent stat-score: 0.16498316498316498
# Average most recent p-value: 0.8912540076434537
# Average most recent clustering coeff: 0.7182950255401366
# Average most recent path length: 4.541473943879125
#
#
# Iters: 1280
# Average most recent Z-score: 0.2447136130628451
# Average most recent stat-score: 0.15879812618943054
# Average most recent p-value: 0.8329419541404275
# Average most recent clustering coeff: 0.734429969511957
# Average most recent path length: 4.559975331483194
#
#
# Average most recent Z-score: 0.3309369229043484
# Average most recent stat-score: 0.14251537935748462
# Average most recent p-value: 0.9264442008607938
# Average most recent clustering coeff: 0.7190130935968938
# Average most recent path length: 4.530681467776749
#
#
# Iters: 1290
# Average most recent Z-score: 0.38478066750720014
# Average most recent stat-score: 0.2265316205533597
# Average most recent p-value: 0.6115930972396809
# Average most recent clustering coeff: 0.7351794444304351
# Average most recent path length: 4.639839654640764
#
#
# Average most recent Z-score: 0.4848354385496119
# Average most recent stat-score: 0.1803030303030303
# Average most recent p-value: 0.7989562063581457
# Average most recent clustering coeff: 0.7215667428111109
# Average most recent path length: 4.273203823620105
#
#
# Iters: 1300
# Average most recent Z-score: 0.3052412043871019
# Average most recent stat-score: 0.20238095238095236
# Average most recent p-value: 0.706060096719542
# Average most recent clustering coeff: 0.7363474096048352
# Average most recent path length: 4.580943570767808
#
#
# Average most recent Z-score: 0.43532239866409134
# Average most recent stat-score: 0.19167869167869167
# Average most recent p-value: 0.7100886262270952
# Average most recent clustering coeff: 0.7219211325037413
# Average most recent path length: 4.318223866790009
#
#
# Iters: 1310
# Average most recent Z-score: 0.2633418407073545
# Average most recent stat-score: 0.20952860722681696
# Average most recent p-value: 0.6563917416489147
# Average most recent clustering coeff: 0.7373320336556982
# Average most recent path length: 4.432007400555041
#
#
# Average most recent Z-score: 0.26174621945340176
# Average most recent stat-score: 0.19883040935672516
# Average most recent p-value: 0.6471363504710154
# Average most recent clustering coeff: 0.7213024749236094
# Average most recent path length: 4.287079864323157
#
#
# Iters: 1320
# Average most recent Z-score: 0.2988702866039875
# Average most recent stat-score: 0.17668279432985315
# Average most recent p-value: 0.8106903378747408
# Average most recent clustering coeff: 0.7372938113488737
# Average most recent path length: 4.474252235584336
#
#
# Average most recent Z-score: 0.4292926364455159
# Average most recent stat-score: 0.20239156268568034
# Average most recent p-value: 0.6631316667376712
# Average most recent clustering coeff: 0.7205669922448062
# Average most recent path length: 4.304347826086956
#
#
# Iters: 1330
# Average most recent Z-score: 0.4521569283804729
# Average most recent stat-score: 0.15418894830659538
# Average most recent p-value: 0.8748965444057987
# Average most recent clustering coeff: 0.7364502366439695
# Average most recent path length: 4.440949737897008
#
#
# Average most recent Z-score: 0.4533566924721935
# Average most recent stat-score: 0.2085949004107572
# Average most recent p-value: 0.6547904385166513
# Average most recent clustering coeff: 0.7201116528413191
# Average most recent path length: 4.3256244218316375
#
#
# Iters: 1340
# Average most recent Z-score: 0.6144963612474518
# Average most recent stat-score: 0.21729055258467023
# Average most recent p-value: 0.6591867811732454
# Average most recent clustering coeff: 0.7365678895276537
# Average most recent path length: 4.456675917360468
#
#
# Average most recent Z-score: 0.4168154494212444
# Average most recent stat-score: 0.2269368880622078
# Average most recent p-value: 0.5839074195944746
# Average most recent clustering coeff: 0.7198278093978874
# Average most recent path length: 4.358618563058896
#
#
# Iters: 1350
# Average most recent Z-score: 0.49756179302243325
# Average most recent stat-score: 0.2271878448349037
# Average most recent p-value: 0.5860870120168887
# Average most recent clustering coeff: 0.7373046161173881
# Average most recent path length: 4.355226641998151
#
#
# Average most recent Z-score: 0.3632529946902357
# Average most recent stat-score: 0.1466305265605306
# Average most recent p-value: 0.8951806039289169
# Average most recent clustering coeff: 0.7193113182470904
# Average most recent path length: 4.4236817761332095
#
#
# Iters: 1360
# Average most recent Z-score: 0.6075183460003589
# Average most recent stat-score: 0.22275273745861982
# Average most recent p-value: 0.622686414524842
# Average most recent clustering coeff: 0.7354970681625388
# Average most recent path length: 4.3811285846438475
#
#
# Average most recent Z-score: 0.3632529946902357
# Average most recent stat-score: 0.1756160338069074
# Average most recent p-value: 0.8291038963369104
# Average most recent clustering coeff: 0.7193928105798445
# Average most recent path length: 4.413197656490904
#
#
# Iters: 1370
# Average most recent Z-score: 0.6178588866741418
# Average most recent stat-score: 0.25572425940072996
# Average most recent p-value: 0.48094335645069614
# Average most recent clustering coeff: 0.7363796435237432
# Average most recent path length: 4.308356460067839
#
#
# Average most recent Z-score: 0.40326017715430923
# Average most recent stat-score: 0.21812552772305094
# Average most recent p-value: 0.672587023212107
# Average most recent clustering coeff: 0.720950056600057
# Average most recent path length: 4.4736355226642
#
#
# Iters: 1380
# Average most recent Z-score: 0.5757942262138861
# Average most recent stat-score: 0.24532085561497327
# Average most recent p-value: 0.5343906300935714
# Average most recent clustering coeff: 0.7353632447943935
# Average most recent path length: 4.311748381128584
#
#
# Average most recent Z-score: 0.34923591047080854
# Average most recent stat-score: 0.21461675579322637
# Average most recent p-value: 0.6845497660150316
# Average most recent clustering coeff: 0.7211925978279998
# Average most recent path length: 4.4933703361085415
#
#
# Iters: 1390
# Average most recent Z-score: 0.3287572011031201
# Average most recent stat-score: 0.17694488747120327
# Average most recent p-value: 0.8234077002764071
# Average most recent clustering coeff: 0.7334172180421678
# Average most recent path length: 4.269195189639222
#
#
# Average most recent Z-score: 0.3526382144703352
# Average most recent stat-score: 0.19946524064171123
# Average most recent p-value: 0.7240092666362433
# Average most recent clustering coeff: 0.7208017917404571
# Average most recent path length: 4.515263644773358
#
#
# Iters: 1400
# Average most recent Z-score: 0.3257011671158149
# Average most recent stat-score: 0.18016297428062134
# Average most recent p-value: 0.8128320115696855
# Average most recent clustering coeff: 0.7341306744530075
# Average most recent path length: 4.293555349984582
#
#
# Average most recent Z-score: 0.36159025767011377
# Average most recent stat-score: 0.21613190730837792
# Average most recent p-value: 0.6477419875284686
# Average most recent clustering coeff: 0.7207831421175174
# Average most recent path length: 4.572001233425841
#
#
# Iters: 1410
# Average most recent Z-score: 0.37593609002026857
# Average most recent stat-score: 0.2228956228956229
# Average most recent p-value: 0.5977147507560177
# Average most recent clustering coeff: 0.7352879314840282
# Average most recent path length: 4.269195189639223
#
#
# Average most recent Z-score: 0.32016538470109396
# Average most recent stat-score: 0.21567077423854916
# Average most recent p-value: 0.5629453846916431
# Average most recent clustering coeff: 0.7206679915318278
# Average most recent path length: 4.597903176071539
#
#
# Iters: 1420
# Average most recent Z-score: 0.37593609002026857
# Average most recent stat-score: 0.16346801346801346
# Average most recent p-value: 0.8496905151874566
# Average most recent clustering coeff: 0.7348194808440457
# Average most recent path length: 4.272895467160037
#
#
# Average most recent Z-score: 0.40543156322584695
# Average most recent stat-score: 0.18575851393188855
# Average most recent p-value: 0.7077471165831349
# Average most recent clustering coeff: 0.7249407369344781
# Average most recent path length: 4.313906876349059
#
#
# Iters: 1430
# Average most recent Z-score: 0.279672948975052
# Average most recent stat-score: 0.15789473684210528
# Average most recent p-value: 0.8385550077392949
# Average most recent clustering coeff: 0.7353301523330456
# Average most recent path length: 4.33240826395313
#
#
# Average most recent Z-score: 0.45639733364157237
# Average most recent stat-score: 0.20211923153099623
# Average most recent p-value: 0.7016326305136661
# Average most recent clustering coeff: 0.7226087655670382
# Average most recent path length: 4.297563983965464
#
#
# Iters: 1440
# Average most recent Z-score: 0.2848928894489196
# Average most recent stat-score: 0.17592592592592593
# Average most recent p-value: 0.754854991677659
# Average most recent clustering coeff: 0.734868436458714
# Average most recent path length: 4.262719703977798
#
#
# Average most recent Z-score: 0.4076070225917808
# Average most recent stat-score: 0.14539685000043057
# Average most recent p-value: 0.8287282957699013
# Average most recent clustering coeff: 0.7204817425590281
# Average most recent path length: 4.35522664199815
#
#
# Iters: 1450
# Average most recent Z-score: 0.3886664298039178
# Average most recent stat-score: 0.16326168957747902
# Average most recent p-value: 0.8359608203868195
# Average most recent clustering coeff: 0.7348070240112591
# Average most recent path length: 4.277829170521122
#
#
# Average most recent Z-score: 0.46084502861742555
# Average most recent stat-score: 0.20578332343038222
# Average most recent p-value: 0.6850380233410118
# Average most recent clustering coeff: 0.7198429852699876
# Average most recent path length: 4.366944187480727
#
#
# Iters: 1460
# Average most recent Z-score: 0.551450695216073
# Average most recent stat-score: 0.23564072093483857
# Average most recent p-value: 0.5555412267363832
# Average most recent clustering coeff: 0.7357862584794016
# Average most recent path length: 4.296022201665125
#
#
# Average most recent Z-score: 0.46381916160403985
# Average most recent stat-score: 0.18894830659536543
# Average most recent p-value: 0.7722798104648443
# Average most recent clustering coeff: 0.7194060790401092
# Average most recent path length: 4.325316065371569
#
#
# Iters: 1470
# Average most recent Z-score: 0.48234041931827926
# Average most recent stat-score: 0.1874889243310296
# Average most recent p-value: 0.7297039856098765
# Average most recent clustering coeff: 0.7360069103116723
# Average most recent path length: 4.338267036694418
#
#
# Average most recent Z-score: 0.39903523044597766
# Average most recent stat-score: 0.16835016835016836
# Average most recent p-value: 0.7988254929811678
# Average most recent clustering coeff: 0.7197525258353386
# Average most recent path length: 4.252235584335492
#
#
# Iters: 1480
# Average most recent Z-score: 0.4006359334177012
# Average most recent stat-score: 0.180176376770804
# Average most recent p-value: 0.8044048429511791
# Average most recent clustering coeff: 0.7348309589280998
# Average most recent path length: 4.425531914893617
#
#
# Average most recent Z-score: 0.43896756294195777
# Average most recent stat-score: 0.18903318903318903
# Average most recent p-value: 0.7735665325585336
# Average most recent clustering coeff: 0.720025836703747
# Average most recent path length: 4.279370952821462
#
#
# Iters: 1490
# Average most recent Z-score: 0.403163450922355
# Average most recent stat-score: 0.18463270475654378
# Average most recent p-value: 0.7271511348036493
# Average most recent clustering coeff: 0.7374093166694918
# Average most recent path length: 4.381745297563985
#
#
# Average most recent Z-score: 0.4474843416086037
# Average most recent stat-score: 0.1721981721981722
# Average most recent p-value: 0.860808319682366
# Average most recent clustering coeff: 0.7201807039493188
# Average most recent path length: 4.293246993524514

# %%
def find_keystones(graph, num_keystones, verbose=False):
    prox_keystones = []
    prox_cent = nx.betweenness_centrality(graph)
    for i in range(num_keystones):
        keystone = max(prox_cent.items(), key=lambda x: x[1])
        prox_cent.pop(keystone[0])
        prox_keystones.append(keystone)
    if verbose:
        print("Proximity Keystones & Their centrailty score")
        for i in prox_keystones: 
            print(f"{i}")
    return prox_keystones

def make_graphs(lot, label = ""):
    plen = []
    cavg = []
    z = []
    stats = []
    ps = []
    for g in lot:
        p_lengths, cluster_avgs, zs, samps, hist_gs = g
        plen.append(p_lengths)
        cavg.append(cluster_avgs)
        z.append(zs)
        stats.append([s[0] for s in samps])
        ps.append([s[1] for s in samps])
    plen = np.array(plen).mean(axis = 0)
    cavg = np.array(cavg).mean(axis = 0)
    z = np.array(z).mean(axis = 0)
    stats = np.array(stats).mean(axis = 0)
    ps = np.array(ps).mean(axis = 0)
    
    plt.plot(np.arange(1500), plen, linewidth=1)
    plt.xlabel('Timesteps')
    plt.ylabel('Average Path Length')
    plt.title(label)
    plt.ylim([2, 6.0])
    plt.savefig(f"./imgs/{label}APlens.png", dpi=500)
    plt.show()
    
    plt.plot(np.arange(1500), cavg, linewidth=1)
    plt.xlabel('Timesteps')
    plt.ylabel('Average Clustering Coefficient')
    plt.title(label)
    plt.ylim([0, 1.0])
    plt.savefig(f"./imgs/{label}ClusteringCoeff.png", dpi=500)
    plt.show()
    
    plt.plot(np.arange(1500), z, label = "Z-test score", linewidth=1)
    plt.xlabel('Timesteps')
    plt.ylabel('Average Z-score')
    plt.title(label)
    plt.ylim([0, 6.0])
    plt.savefig(f"./imgs/{label}Zscores.png", dpi=500)
    plt.show()
    
    plt.plot(np.arange(1500), stats, label = "KS Test Statistic", linewidth=1)
    plt.plot(np.arange(1500), ps, label = "KS p-values")
    plt.xlabel('Timesteps')
    plt.ylabel('Two-Sample KS Test')
    plt.ylim([0, 1.0])
    plt.title(label)
    plt.legend()
    plt.savefig(f"./imgs/{label}K2.png", dpi=500)
    plt.show()

def find_avg_keystones(lot, label = ""):
    i = 0
    all_keys = []
    for g in lot:
        p_lengths, cluster_avgs, zs, samps, hist_gs = g
        all_keys.append([c[1] for c in find_keystones(hist_gs[-1], 47, verbose = False)])
        
    plt.plot(np.arange(47), sorted(np.array(all_keys).mean(axis = 0)), label = "Betweenness Centrality", linewidth=1)
    plt.xlabel('Agents')
    plt.ylabel('Betweenness Centrality')
    plt.ylim([0, 0.08])
    plt.title(label)
    plt.legend()
    plt.savefig(f"./imgs/{label}avg_keystones.png", dpi=500)
    plt.show()

# %%
two = res[0]
four = res[1]
five = res[2]
make_graphs(two, "Gamma = 0.1")
make_graphs(four, "Gamma = 0.5")
make_graphs(five, "Gamma = 0.7")
find_avg_keystones(two, "Gamma = 0.1")
find_avg_keystones(four, "Gamma = 0.5")
find_avg_keystones(five, "Gamma = 0.7")
