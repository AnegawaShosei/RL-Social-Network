# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense, Softmax
import matplotlib.pyplot as plt
import networkx as nx
from scipy.stats import ks_2samp
from graph_utils import avg_path_length
from graph_utils import get_cluster_coeff
from statsmodels import ztest as ztest
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 10
#       8 from graph_utils import avg_path_length
#       9 from graph_utils import get_cluster_coeff
# ---> 10 from statsmodels import ztest as ztest
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
#Run me

nA = 5
class Node:
    '''kekw'''
    def __init__(self, Q):
        self.Q = Q #Q-func
        self.E = [] #Experience pool

def initQ(in_size, i, lr):
    '''Initializes Q-approximator for 
     - in_size : Size of input (should be number of states + number of actions)
     - i : 
    '''
    input_layer = Input(shape = (in_size,))
    dense_1 = Dense(128, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(input_layer)
    dense_2 = Dense(128, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(dense_1)
    dense_3 = Dense(64, activation = 'relu', use_bias = True, kernel_initializer="glorot_uniform")(dense_2)
    o = Dense(1, activation = None, use_bias = True, kernel_initializer="glorot_uniform")(dense_3)
    
    Q = Model(input_layer, o, name = "Q" + str(i))

#     def mse(y_true, y_pred):
#         return tf.math.reduce_mean(tf.math.square(y_true - y_pred)) * 0.5
    
    optimizer = tf.keras.optimizers.SGD(learning_rate = lr, momentum = 0.0)
    loss =  tf.keras.losses.MeanSquaredError()

    Q.compile(loss = loss, optimizer = optimizer)
                           
    return Q

class World:
    def __init__(self, n, num_agents):
        #self.state = np.zeros((num_agents, n * n)) #State, 46 x 100
        self.state_nums = np.zeros((num_agents,), dtype = int)
        self.n = n
        self.G = nx.Graph()
        self.G.add_nodes_from(range(num_agents))
        self.num_agents = num_agents
        
        for m in range(num_agents): #Start agents in random states
            r = np.random.randint(0, n * n)
            #self.state[m, r] = 1
            self.state_nums[m] = r
    
    def get_pos(self):
        out = []
        for i in range(self.num_agents):
            loc = self.state_nums[i]
            y, x = loc // self.n, loc % self.n
            x += np.random.uniform()
            y += np.random.uniform()
            out.append((x, y))
        return dict(enumerate(out, start = 0))
        
    def update_G(self):
        '''
        Searches for agents in the same state, and adds one to their edge's weight
        Also decreases any existing connections that are not maintained's weights by 1
        Removes any connections that have weight leq to 0
        '''
        updated = []
        rewards = np.zeros((self.num_agents, 1))
        for ag in range(self.state_nums.shape[0]): 
            #TODO: Maybe replace with np where to add edges?
            for tg in range(self.state_nums.shape[0]):
                #If same state, create/add weight to edge
                if ag != tg and self.state_nums[ag] == self.state_nums[tg] and (tg, ag) not in updated: 
                    if not self.G.has_edge(ag, tg):            #^ that fixes the double counhting but if i leave it
                        self.G.add_edge(ag, tg, weight = 1)  #it has better time complexity
                    else:
                        self.G.edges[ag, tg]['weight'] += 1 #<- thats why theyre 0.5 
                    updated.append((ag, tg))
                    updated.append((tg, ag))
                    
        for edge in self.G.edges():
            #Decrement all unupdated edges by 1, remove if less than 0
            if edge not in updated:
                self.G.edges[edge]['weight'] -= 0.025
                if self.G.edges[edge]['weight'] <= 0:
                    self.G.remove_edge(edge[0], edge[1])
                else:
                    rewards[edge[0]] += self.G.edges[edge]['weight']
                    rewards[edge[1]] += self.G.edges[edge]['weight']
            else:
                rewards[edge[0]] += self.G.edges[edge]['weight']
                rewards[edge[1]] += self.G.edges[edge]['weight']
            
        return rewards
    
                    
    def take_action(self, agent_id, a):
        #loc = np.argmax(self.state[agent_id, :])
        loc = self.state_nums[agent_id]
        y, x = loc // self.n, loc % self.n
        
        if a == 4: #down
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y + 1) * self.n) + x] = 1
            self.state_nums[agent_id] = ((y + 1) * self.n) + x
        elif a == 1: #up
           # self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y - 1) * self.n) + x] = 1
            self.state_nums[agent_id] = ((y - 1) * self.n) + x
        elif a == 2: #left
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y) * self.n) + x - 1] = 1
            self.state_nums[agent_id] = ((y) * self.n) + x - 1
        elif a == 3: #right
            #self.state[agent_id, loc] = 0
            #self.state[agent_id, ((y) * self.n) + x + 1] = 1  
            self.state_nums[agent_id] = ((y) * self.n) + x + 1
        elif a == 0: #stay
            pass

def get_legals(s, n, nA):
    #Returns an array containig infinity if legal negative infinity if not
    legal_moves = np.ones((nA, 1)) * np.inf
    loc = s #np.argmax(s)
    y, x = loc // n, loc % n
    if y >= n - 1:
        legal_moves[4] = -np.inf
    if y == 0:
        legal_moves[1] = -np.inf
    if x == 0:
        legal_moves[2] = -np.inf
    if x == n - 1:
        legal_moves[3] = -np.inf

    return legal_moves
    
    #Make the graph pretty
def pp_graph(GRAPH_NAME, pos):
    #not short for pee pee graph
    widths = nx.get_edge_attributes(GRAPH_NAME, 'weight')
    nodelist = GRAPH_NAME.nodes()

    plt.figure(figsize=(10,10))

    #pos = nx.spring_layout(GRAPH_NAME)
    nx.draw_networkx_nodes(GRAPH_NAME, pos,
                           nodelist=nodelist,
                           node_size=100,
                           alpha=0.7)
    nx.draw_networkx_edges(GRAPH_NAME, pos,
                           edgelist = widths.keys(),
                           width=[val*1 for val in list(widths.values())],
                           edge_color='black',
                           alpha=0.75)
    plt.box(False)
    plt.show() 

    
def form_2d_graph(snums):
    xout, yout = [], []
    for s in snums:
        y, x = s // n, s % n
        xout.append((x + np.random.uniform())* 10)
        yout.append((y + np.random.uniform()) * 10)
    
    return xout, yout

def plot_2d_graph(x, y):
    fig = plt.figure()
    ax = fig.gca()
    ax.set_xticks(np.arange(0, 100, 10))
    ax.set_yticks(np.arange(0, 100, 10))
    plt.scatter(x, y, s=10)
    plt.grid()
    plt.show()
    
def degree_distribution(graph, name = "bruh"):
    degree_sequence = sorted((d for _, d in graph.degree()), reverse=True)

    plt.figure(name, figsize=(8, 8))
    plt.bar(*np.unique(degree_sequence, return_counts=True))
    plt.xlabel('Degree')
    plt.ylabel('# of Nodes')

    plt.show()

# %%
def monk_it_up(epsilon_func, episode_length = 100, n = 10, y = 0.9, nAgents = 47, lr = 0.001, verbose = 1):
    '''
    Inputs:
     - epsilon_func: Function taht takes a timestep first, and then an agent id i, and returns a
                     epsilon between 0 and 1, keep in mind t starts at 0
     - episode_length: Number of steps in an episode
     - n: dimensions of world, will be nxn size
     - y: discount factor
     - nAgents: number of monkeys
     - lr: Learning rate, controls how fast neural net learns. Careful with putting lr too high, since 0.01 makes 
           gradient bounce around super fast, leading to a lot of nan predictions
     - verbose: 
         - if 0: prints nothing
         - if 1: prints Z-score and KSamps
         - if 2: prints graphs, z-score and Ksamps
           
    Returns:
    world object: Object representing the world, do world.G to get the graph, or world.state_nums for current board
                  state
    Avg path length list: List containing average path legnths every 10 timesteps (CURRENTLY NANS)
    clsuter_avgs: List containing average clustering coefficient every timestep
    zs : Numpy array of z-scores at each timestep (compared to our proximity graph, lower is better)
    samps : listo f KS-2  samples(tuples) at every timestep
    hist_gs : Graph of every timestep
    '''
    p_lengths = []
    cluster_avgs = []
    zs = []
    samps = []
    hist_gs = []
    
    worse_graph = nx.read_adjlist("./prog_g.adjlist")
    w_degree_sequence = np.unique(sorted((d for _, d in worse_graph.degree()), reverse=True), return_counts = True)[1]
    
    all_actions = np.eye(nA, dtype = np.float32)
    state = np.zeros((nA, n * n))
    vec = np.concatenate((state, all_actions), axis = 1)

    def policy(s, n, nA, epsilon, Q):
        legal_moves = get_legals(s, n, nA)
        #Epsilon exploration
        if np.random.uniform() < epsilon:
            r = np.random.randint(0, nA)
            while legal_moves[r] != np.inf:
                r = np.random.randint(0, nA)
            return r

        vec[:, s] = 1    
        out = np.argmax(np.minimum(Q(vec), legal_moves))
        vec[:, s] = 0

        return out

    upd_vec = np.zeros((1, n * n + nA))
    tg_vec = np.zeros((1, n * n + nA))

    def update(s, a, r, sp, gamma, Q):
        upd_vec[0, s] = 1
        upd_vec[0, s + a] = 1


        tg_vec[0, sp] = 1
        ap = policy(sp, n, nA, 0, Q)
        tg_vec[0, ap + sp] = 1
        Q.train_on_batch(upd_vec, r + gamma * Q(tg_vec))
        upd_vec[0, s], upd_vec[0, s + a], tg_vec[0, sp], tg_vec[0, ap + sp]  = 0, 0, 0, 0
        
    agents = [Node(initQ(n * n + nA, i, lr)) for i in range(nAgents)]

    world = World(n, nAgents)

    for t in range(episode_length):
        if t % 10 == 0 and verbose >= 1:
            print(f"Iter : {t}")
        

        for agent, i in zip(agents, range(nAgents)):
            epsilon = epsilon_func(t, i)
            sars = np.zeros((4,), dtype = int)
            s = world.state_nums[i]
            a = policy(s, n, nA, epsilon, agent.Q)

            world.take_action(i, a)

            sars[0] = s
            sars[1] = a
            sars[3] = world.state_nums[i]

            agent.E.append(sars) #r will come later

        R = world.update_G()

        for agent, i in zip(agents, range(nAgents)):
            agent.E[t][2] = R[i]
            s, a, r, sp = agent.E[np.random.choice(len(agent.E))]
            #s, a, r, sp = agent.E[t]
            #update(s, a, r, sp, y, agent.Q)
            
        p_len = None
        if t % 5 == 0:
            p_len = avg_path_length(world.G)
            p_lengths.append(p_len)
        if t % 5 == 0 and verbose >= 2:
            pp_graph(world.G, world.get_pos())
            print(f"Average path length: {p_len}")
            
        
        degree_sequence = np.unique(sorted((d for _, d in world.G.degree()), reverse=True),
                                    return_counts = True)[1]
        top = (degree_sequence.mean() - w_degree_sequence.mean()) 
        bot1 = np.square(np.std(degree_sequence) / np.sqrt(degree_sequence.shape[0]))
        bot2 = np.square(np.std(w_degree_sequence)) / np.sqrt(w_degree_sequence.shape[0])
        z = top / np.sqrt(bot1 + bot2)
        

        zs.append(z)

        s = ks_2samp(degree_sequence, w_degree_sequence)
        samps.append(s)
        if t % 10 == 0 and verbose >= 1:
            print(f"Z-score : {z}")
            print(f"ks_2 sample : {s}")

        hist_gs.append(world.G.copy())
        cluster_avgs.append(nx.average_clustering(world.G))
        
    return world, p_lengths, cluster_avgs, np.array(zs), samps, hist_gs

# %%
def mem_friendly(epsilon_func, episode_length = 500, n = 7, y = 0.9, nAgents = 47, lr = 0.001, verbose = 1):
    '''
    Inputs:
     - epsilon_func: Function taht takes a timestep first, and then an agent id i, and returns a
                     epsilon between 0 and 1, keep in mind t starts at 0
     - episode_length: Number of steps in an episode
     - n: dimensions of world, will be nxn size
     - y: discount factor
     - nAgents: number of monkeys
     - lr: Learning rate, controls how fast neural net learns. Careful with putting lr too high, since 0.01 makes 
           gradient bounce around super fast, leading to a lot of nan predictions
     - verbose: 
         - if 0: prints nothing
         - if 1: prints Z-score and KSamps
         - if 2: prints graphs, z-score and Ksamps
           
    Returns:
    world object: Object representing the world, do world.G to get the graph, or world.state_nums for current board
                  state
    Avg path length list: List containing average path legnths every 10 timesteps (CURRENTLY NANS)
    clsuter_avgs: List containing average clustering coefficient every timestep
    zs : Numpy array of z-scores at each timestep (compared to our proximity graph, lower is better)
    samps : listo f KS-2  samples(tuples) at every timestep
    hist_gs : Graph of every timestep
    '''
    p_lengths = []
    cluster_avgs = []
    zs = []
    samps = []
    
    worse_graph = nx.read_adjlist("./prog_g.adjlist")
    w_degree_sequence = np.unique(sorted((d for _, d in worse_graph.degree()), reverse=True), return_counts = True)[1]
    
    all_actions = np.eye(nA, dtype = np.float32)
    state = np.zeros((nA, n * n))
    vec = np.concatenate((state, all_actions), axis = 1)

    def policy(s, n, nA, epsilon, Q):
        legal_moves = get_legals(s, n, nA)
        #Epsilon exploration
        if np.random.uniform() < epsilon:
            r = np.random.randint(0, nA)
            while legal_moves[r] != np.inf:
                r = np.random.randint(0, nA)
            return r

        vec[:, s] = 1    
        out = np.argmax(np.minimum(Q(vec), legal_moves))
        vec[:, s] = 0

        return out

    upd_vec = np.zeros((1, n * n + nA))
    tg_vec = np.zeros((1, n * n + nA))

    def update(s, a, r, sp, gamma, Q):
        upd_vec[0, s] = 1
        upd_vec[0, s + a] = 1


        tg_vec[0, sp] = 1
        ap = policy(sp, n, nA, 0, Q)
        tg_vec[0, ap + sp] = 1
        Q.train_on_batch(upd_vec, r + gamma * Q(tg_vec))
        upd_vec[0, s], upd_vec[0, s + a], tg_vec[0, sp], tg_vec[0, ap + sp]  = 0, 0, 0, 0
        
    agents = [Node(initQ(n * n + nA, i, lr)) for i in range(nAgents)]

    world = World(n, nAgents)

    for t in range(episode_length):
        if t % 10 == 0 and verbose >= 1:
            print(f"Iter : {t}")
        

        for agent, i in zip(agents, range(nAgents)):
            epsilon = epsilon_func(t, i)
            sars = np.zeros((4,), dtype = int)
            s = world.state_nums[i]
            a = policy(s, n, nA, epsilon, agent.Q)

            world.take_action(i, a)

            sars[0] = s
            sars[1] = a
            sars[3] = world.state_nums[i]

            agent.E.append(sars) #r will come later

        R = world.update_G()

        for agent, i in zip(agents, range(nAgents)):
            agent.E[t][2] = R[i]
            s, a, r, sp = agent.E[np.random.choice(len(agent.E))]
            #s, a, r, sp = agent.E[t]
            #update(s, a, r, sp, y, agent.Q)
            

        p_len = avg_path_length(world.G)
        p_lengths.append(p_len)
        if t % 5 == 0 and verbose >= 2:
            pp_graph(world.G, world.get_pos())
            print(f"Average path length: {p_len}")
            
        
        degree_sequence = np.unique(sorted((d for _, d in world.G.degree()), reverse=True),
                                    return_counts = True)[1]
        top = (degree_sequence.mean() - w_degree_sequence.mean()) 
        bot1 = np.square(np.std(degree_sequence) / np.sqrt(degree_sequence.shape[0]))
        bot2 = np.square(np.std(w_degree_sequence)) / np.sqrt(w_degree_sequence.shape[0])
        z = top / np.sqrt(bot1 + bot2)
        

        zs.append(z)

        s = ks_2samp(degree_sequence, w_degree_sequence)
        samps.append(s)
        if t % 10 == 0 and verbose >= 1:
            print(f"Z-score : {z}")
            print(f"ks_2 sample : {s}")

        cluster_avgs.append(nx.average_clustering(world.G))
        
    return p_lengths, cluster_avgs, np.array(zs), samps

# %%
nAgents = 47
eps_funcs = np.random.uniform(0.2, 0.5, (nAgents,))
e_fixed = lambda t, i: 0.3
e_fixed_2 = lambda t, i: 0.4
e_decay = lambda t, i : 1 / (t + 1)
e_brainoff = lambda t, i: 1

res = [0] * 3

#250 Iters, -0.025
for e, j in zip((e_fixed, e_brainoff), range(2)):
    res[j] = []
    for i in range(100):
        print(f"iter: {i}")
        pl, cl, z, samp = mem_friendly(e, 500, n  = 7,nAgents = 47, verbose = 0)
        res[j].append((pl, cl, z, samp))
        #pp_graph(res[i][0].G, res[i][0].get_pos())
# Out:
# iter: 0
# 2022-11-24 19:16:43.380070: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# iter: 1
# iter: 2
# iter: 3
# iter: 4
# iter: 5
# iter: 6
# iter: 7
# iter: 8
# iter: 9
# iter: 10
# iter: 11
# iter: 12
# iter: 13
# iter: 14
# iter: 15
# iter: 16
# iter: 17
# iter: 18
# iter: 19
# iter: 20
# iter: 21
# iter: 22
# iter: 23
# iter: 24
# iter: 25
# iter: 26
# iter: 27
# iter: 28
# iter: 29
# iter: 30
# iter: 31
# iter: 32
# iter: 33
# iter: 34
# iter: 35
# iter: 36
# iter: 37
# iter: 38
# iter: 39
# iter: 40
# iter: 41
# iter: 42
# iter: 43
# iter: 44
# iter: 45
# iter: 46
# iter: 47
# iter: 48
# iter: 49
# iter: 50
# iter: 51
# iter: 52
# iter: 53
# iter: 54
# iter: 55
# iter: 56
# iter: 57
# iter: 58
# iter: 59
# iter: 60
# iter: 61
# iter: 62
# iter: 63
# iter: 64
# iter: 65
# iter: 66
# iter: 67
# iter: 68
# iter: 69
# iter: 70
# iter: 71
# iter: 72
# iter: 73
# iter: 74
# iter: 75
# iter: 76
# iter: 77
# iter: 78
# iter: 79
# iter: 80
# iter: 81
# iter: 82
# iter: 83
# iter: 84
# iter: 85
# iter: 86
# iter: 87
# iter: 88
# iter: 89
# iter: 90
# iter: 91
# iter: 92
# iter: 93
# iter: 94
# iter: 95
# iter: 96
# iter: 97
# iter: 98
# iter: 99
# iter: 0
# iter: 1
# iter: 2
# iter: 3
# iter: 4
# iter: 5
# iter: 6
# iter: 7
# iter: 8
# iter: 9
# iter: 10
# iter: 11
# iter: 12
# iter: 13
# iter: 14
# iter: 15
# iter: 16
# iter: 17
# iter: 18
# iter: 19
# iter: 20
# iter: 21
# iter: 22
# iter: 23
# iter: 24
# iter: 25
# iter: 26
# iter: 27
# iter: 28
# iter: 29
# iter: 30
# iter: 31
# iter: 32
# iter: 33
# iter: 34
# iter: 35
# iter: 36
# iter: 37
# iter: 38
# iter: 39
# iter: 40
# iter: 41
# iter: 42
# iter: 43
# iter: 44
# iter: 45
# iter: 46
# iter: 47
# iter: 48
# iter: 49
# iter: 50
# iter: 51
# iter: 52
# iter: 53
# iter: 54
# iter: 55
# iter: 56
# iter: 57
# iter: 58
# iter: 59
# iter: 60
# iter: 61
# iter: 62
# iter: 63
# iter: 64
# iter: 65
# iter: 66
# iter: 67
# iter: 68
# iter: 69
# iter: 70
# iter: 71
# iter: 72
# iter: 73
# iter: 74
# iter: 75
# iter: 76
# iter: 77
# iter: 78
# iter: 79
# iter: 80
# iter: 81
# iter: 82
# iter: 83
# iter: 84
# iter: 85
# iter: 86
# iter: 87
# iter: 88
# iter: 89
# iter: 90
# iter: 91
# iter: 92
# iter: 93
# iter: 94
# iter: 95
# iter: 96
# iter: 97
# iter: 98
# iter: 99

# %%
res.pop(-1)
# Out:
# 0

# %%
for iters in range(150, 500, 10):
    print(f"Iters: {iters}")
    for res_e in res:
        mins = []
        stat = []
        p = []
        cluss = []
        pplens = []
        for run in res_e:
            plens, clus_avgs, zs, samp = run
            mins.append(zs[iters])
            stat.append(samp[iters][0])
            p.append(samp[iters][1])
            cluss.append(clus_avgs[iters])
            pplens.append(plens[iters])

        print(f"Average most recent Z-score: {np.mean(mins)}")
        print(f"Average most recent stat-score: {np.mean(stat)}")
        print(f"Average most recent p-value: {np.mean(p)}")
        print(f"Average most recent clustering coeff: {np.mean(cluss)}")
        print(f"Average most recent path length: {np.mean(pplens)}")
# Out:
# Iters: 150
# Average most recent Z-score: 1.0308504921462422
# Average most recent stat-score: 0.30945414547537986
# Average most recent p-value: 0.34792842148083997
# Average most recent clustering coeff: 0.6047973530871337
# Average most recent path length: 4.396623496762257
# Average most recent Z-score: 1.2430014801531086
# Average most recent stat-score: 0.34025053760309176
# Average most recent p-value: 0.28178144518697407
# Average most recent clustering coeff: 0.635695711115002
# Average most recent path length: 4.21695189639223
# Iters: 160
# Average most recent Z-score: 0.97022008782117
# Average most recent stat-score: 0.28572386488640356
# Average most recent p-value: 0.42022221072043336
# Average most recent clustering coeff: 0.6070806455415688
# Average most recent path length: 4.5093802035152635
# Average most recent Z-score: 1.2696008894355755
# Average most recent stat-score: 0.3565475186578127
# Average most recent p-value: 0.2352530815176551
# Average most recent clustering coeff: 0.6455188825512768
# Average most recent path length: 4.25186864014801
# Iters: 170
# Average most recent Z-score: 1.0150193684252764
# Average most recent stat-score: 0.3039436774955351
# Average most recent p-value: 0.37517015514857943
# Average most recent clustering coeff: 0.6103115125137849
# Average most recent path length: 4.520814061054579
# Average most recent Z-score: 1.2841352705509217
# Average most recent stat-score: 0.35022419737125615
# Average most recent p-value: 0.24337289415345226
# Average most recent clustering coeff: 0.6514475769933985
# Average most recent path length: 4.399431082331175
# Iters: 180
# Average most recent Z-score: 0.9752802759307516
# Average most recent stat-score: 0.29655859594481887
# Average most recent p-value: 0.3959827551950991
# Average most recent clustering coeff: 0.6125516355506053
# Average most recent path length: 4.452927844588344
# Average most recent Z-score: 1.3421399765107085
# Average most recent stat-score: 0.3698120400411422
# Average most recent p-value: 0.219422074576219
# Average most recent clustering coeff: 0.6561886789831073
# Average most recent path length: 4.299796484736355
# Iters: 190
# Average most recent Z-score: 0.9629403477478081
# Average most recent stat-score: 0.29644509004067826
# Average most recent p-value: 0.4155447799466656
# Average most recent clustering coeff: 0.6151155760537379
# Average most recent path length: 4.407608695652174
# Average most recent Z-score: 1.328939867707667
# Average most recent stat-score: 0.3734063136296109
# Average most recent p-value: 0.20662559649952958
# Average most recent clustering coeff: 0.6618388315975209
# Average most recent path length: 4.268765032377429
# Iters: 200
# Average most recent Z-score: 0.9771835409215979
# Average most recent stat-score: 0.28941988695858667
# Average most recent p-value: 0.42420370075538444
# Average most recent clustering coeff: 0.615746581717308
# Average most recent path length: 4.511193339500462
# Average most recent Z-score: 1.3516282824378514
# Average most recent stat-score: 0.37354507257448427
# Average most recent p-value: 0.20668166258905493
# Average most recent clustering coeff: 0.6676887783794824
# Average most recent path length: 4.251202590194265
# Iters: 210
# Average most recent Z-score: 1.0011444290772649
# Average most recent stat-score: 0.30274228557819893
# Average most recent p-value: 0.37882394233991035
# Average most recent clustering coeff: 0.6177018863952743
# Average most recent path length: 4.470342275670675
# Average most recent Z-score: 1.3394015406582807
# Average most recent stat-score: 0.37090872444548906
# Average most recent p-value: 0.2141163419325198
# Average most recent clustering coeff: 0.6730468072918231
# Average most recent path length: 4.397631822386679
# Iters: 220
# Average most recent Z-score: 0.9519174748452763
# Average most recent stat-score: 0.304571186510428
# Average most recent p-value: 0.38573575019646716
# Average most recent clustering coeff: 0.620966435407278
# Average most recent path length: 4.443395004625347
# Average most recent Z-score: 1.344201511413777
# Average most recent stat-score: 0.36348684648684654
# Average most recent p-value: 0.2454175471968607
# Average most recent clustering coeff: 0.6774798999435478
# Average most recent path length: 4.333057354301572
# Iters: 230
# Average most recent Z-score: 0.9621044909041631
# Average most recent stat-score: 0.3001155100919033
# Average most recent p-value: 0.396569181093862
# Average most recent clustering coeff: 0.6228932725424833
# Average most recent path length: 4.451868640148011
# Average most recent Z-score: 1.3735979921727774
# Average most recent stat-score: 0.3796286409668763
# Average most recent p-value: 0.20414120266147465
# Average most recent clustering coeff: 0.683574103209951
# Average most recent path length: 4.1974791859389455
# Iters: 240
# Average most recent Z-score: 0.9150040740131881
# Average most recent stat-score: 0.28796402470938076
# Average most recent p-value: 0.42077647907283605
# Average most recent clustering coeff: 0.6246014753608126
# Average most recent path length: 4.484209065679926
# Average most recent Z-score: 1.3459769735209721
# Average most recent stat-score: 0.3630894742512389
# Average most recent p-value: 0.2342792205219891
# Average most recent clustering coeff: 0.6897906305105463
# Average most recent path length: 4.308547641073081
# Iters: 250
# Average most recent Z-score: 0.9133148903420154
# Average most recent stat-score: 0.2884949672360663
# Average most recent p-value: 0.4117401971997262
# Average most recent clustering coeff: 0.627691802085816
# Average most recent path length: 4.432030527289547
# Average most recent Z-score: 1.3576949398224056
# Average most recent stat-score: 0.3765664360149655
# Average most recent p-value: 0.2046392505883846
# Average most recent clustering coeff: 0.6921398527816055
# Average most recent path length: 4.3948011100832565
# Iters: 260
# Average most recent Z-score: 0.8891930713323475
# Average most recent stat-score: 0.29118121189096424
# Average most recent p-value: 0.4052241151086524
# Average most recent clustering coeff: 0.6310740785691094
# Average most recent path length: 4.4522109158186876
# Average most recent Z-score: 1.3923814076117957
# Average most recent stat-score: 0.3780611496346791
# Average most recent p-value: 0.19820523973124032
# Average most recent clustering coeff: 0.6949053252400782
# Average most recent path length: 4.3169842738205375
# Iters: 270
# Average most recent Z-score: 0.9196855331430526
# Average most recent stat-score: 0.288016036594984
# Average most recent p-value: 0.41479115045403037
# Average most recent clustering coeff: 0.6325095223749735
# Average most recent path length: 4.445231267345051
# Average most recent Z-score: 1.3712164684070778
# Average most recent stat-score: 0.37549613351045247
# Average most recent p-value: 0.20934076283184497
# Average most recent clustering coeff: 0.6974034437113943
# Average most recent path length: 4.32663737280296
# Iters: 280
# Average most recent Z-score: 0.8764947636423104
# Average most recent stat-score: 0.2816366431163847
# Average most recent p-value: 0.4359512580302883
# Average most recent clustering coeff: 0.6342646673549779
# Average most recent path length: 4.483316373728029
# Average most recent Z-score: 1.415477072847895
# Average most recent stat-score: 0.393726075395193
# Average most recent p-value: 0.18152936376107745
# Average most recent clustering coeff: 0.7003425037219186
# Average most recent path length: 4.255393154486586
# Iters: 290
# Average most recent Z-score: 0.8428669442008325
# Average most recent stat-score: 0.27911020867677216
# Average most recent p-value: 0.4338882483502382
# Average most recent clustering coeff: 0.6359913912615195
# Average most recent path length: 4.482460684551342
# Average most recent Z-score: 1.4055278135640423
# Average most recent stat-score: 0.3835710123210123
# Average most recent p-value: 0.19941049049036522
# Average most recent clustering coeff: 0.7046647344402449
# Average most recent path length: 4.3418177613321
# Iters: 300
# Average most recent Z-score: 0.8362414605494857
# Average most recent stat-score: 0.27311844373376887
# Average most recent p-value: 0.4618038525220449
# Average most recent clustering coeff: 0.6374922214893702
# Average most recent path length: 4.485444033302497
# Average most recent Z-score: 1.388424032049848
# Average most recent stat-score: 0.37029959746136215
# Average most recent p-value: 0.22357175462516518
# Average most recent clustering coeff: 0.7071695389713409
# Average most recent path length: 4.3284690101757635
# Iters: 310
# Average most recent Z-score: 0.8475836771042593
# Average most recent stat-score: 0.26947324785637483
# Average most recent p-value: 0.46318571634238104
# Average most recent clustering coeff: 0.6385873749562547
# Average most recent path length: 4.468418131359852
# Average most recent Z-score: 1.4004104817575773
# Average most recent stat-score: 0.3916475011916188
# Average most recent p-value: 0.16472680115665242
# Average most recent clustering coeff: 0.710091763112088
# Average most recent path length: 4.228917668825162
# Iters: 320
# Average most recent Z-score: 0.8078486381726752
# Average most recent stat-score: 0.26607632103878237
# Average most recent p-value: 0.4853249095090706
# Average most recent clustering coeff: 0.6398375308969507
# Average most recent path length: 4.508880666049954
# Average most recent Z-score: 1.4364800196320815
# Average most recent stat-score: 0.40200754311048426
# Average most recent p-value: 0.1646278861516376
# Average most recent clustering coeff: 0.7153485654765359
# Average most recent path length: 4.25540240518039
# Iters: 330
# Average most recent Z-score: 0.8115143863209257
# Average most recent stat-score: 0.262501639141732
# Average most recent p-value: 0.48727537470711973
# Average most recent clustering coeff: 0.6416275714593815
# Average most recent path length: 4.532127659574468
# Average most recent Z-score: 1.400645262912579
# Average most recent stat-score: 0.37908626177743826
# Average most recent p-value: 0.19418530676606754
# Average most recent clustering coeff: 0.7170643292833208
# Average most recent path length: 4.3054671600370025
# Iters: 340
# Average most recent Z-score: 0.7863162692345008
# Average most recent stat-score: 0.25967404130097627
# Average most recent p-value: 0.5028845526889062
# Average most recent clustering coeff: 0.644081922473942
# Average most recent path length: 4.466711378353377
# Average most recent Z-score: 1.4613300468041501
# Average most recent stat-score: 0.3929845775139892
# Average most recent p-value: 0.16991686799615122
# Average most recent clustering coeff: 0.7183878571243411
# Average most recent path length: 4.370490286771507
# Iters: 350
# Average most recent Z-score: 0.8130137422833061
# Average most recent stat-score: 0.264102491119132
# Average most recent p-value: 0.4759061883976454
# Average most recent clustering coeff: 0.6443511663222106
# Average most recent path length: 4.448015726179464
# Average most recent Z-score: 1.3711425482855524
# Average most recent stat-score: 0.37275707625707616
# Average most recent p-value: 0.19539916836571541
# Average most recent clustering coeff: 0.7206687671275853
# Average most recent path length: 4.271914893617022
# Iters: 360
# Average most recent Z-score: 0.7703961984247855
# Average most recent stat-score: 0.2642578001633729
# Average most recent p-value: 0.469871571149142
# Average most recent clustering coeff: 0.6469288488517464
# Average most recent path length: 4.445744680851065
# Average most recent Z-score: 1.4147549473137826
# Average most recent stat-score: 0.3748681392137274
# Average most recent p-value: 0.20915739166856073
# Average most recent clustering coeff: 0.7242478741826726
# Average most recent path length: 4.282793709528215
# Iters: 370
# Average most recent Z-score: 0.7977794382768986
# Average most recent stat-score: 0.2664872391540349
# Average most recent p-value: 0.4817887626460849
# Average most recent clustering coeff: 0.6480684792098351
# Average most recent path length: 4.521535615171138
# Average most recent Z-score: 1.4516288247246456
# Average most recent stat-score: 0.40152068764568766
# Average most recent p-value: 0.18232071036949538
# Average most recent clustering coeff: 0.7263779315813383
# Average most recent path length: 4.3035106382978725
# Iters: 380
# Average most recent Z-score: 0.7691455379140401
# Average most recent stat-score: 0.2583547369383282
# Average most recent p-value: 0.5066155082316008
# Average most recent clustering coeff: 0.6500664647038069
# Average most recent path length: 4.486480111008326
# Average most recent Z-score: 1.5098936889834118
# Average most recent stat-score: 0.405841961959609
# Average most recent p-value: 0.1607574804671975
# Average most recent clustering coeff: 0.7292449524586366
# Average most recent path length: 4.3306382978723414
# Iters: 390
# Average most recent Z-score: 0.7687080045649135
# Average most recent stat-score: 0.2653273352034962
# Average most recent p-value: 0.4755261569036214
# Average most recent clustering coeff: 0.6512765950393059
# Average most recent path length: 4.456341350601296
# Average most recent Z-score: 1.4310256237513945
# Average most recent stat-score: 0.39725965700965704
# Average most recent p-value: 0.17214749529074555
# Average most recent clustering coeff: 0.732596462636245
# Average most recent path length: 4.294232192414431
# Iters: 400
# Average most recent Z-score: 0.7079896764546441
# Average most recent stat-score: 0.2503270615263649
# Average most recent p-value: 0.5283151773452156
# Average most recent clustering coeff: 0.651647698085352
# Average most recent path length: 4.466234967622571
# Average most recent Z-score: 1.4589597222661337
# Average most recent stat-score: 0.3946421495171495
# Average most recent p-value: 0.16617277039361045
# Average most recent clustering coeff: 0.7354577432358512
# Average most recent path length: 4.230319148936172
# Iters: 410
# Average most recent Z-score: 0.7420122178116385
# Average most recent stat-score: 0.2607156164698735
# Average most recent p-value: 0.4913230321788813
# Average most recent clustering coeff: 0.6528076564671487
# Average most recent path length: 4.452701202590194
# Average most recent Z-score: 1.520995601918154
# Average most recent stat-score: 0.41429126755597345
# Average most recent p-value: 0.1401323031059574
# Average most recent clustering coeff: 0.7381707988127681
# Average most recent path length: 4.317890841813136
# Iters: 420
# Average most recent Z-score: 0.7469994022994277
# Average most recent stat-score: 0.253177423926263
# Average most recent p-value: 0.5224209620158347
# Average most recent clustering coeff: 0.6529035806302214
# Average most recent path length: 4.502303422756707
# Average most recent Z-score: 1.5150541289190729
# Average most recent stat-score: 0.4129400207635501
# Average most recent p-value: 0.13938415409354377
# Average most recent clustering coeff: 0.7383921027383551
# Average most recent path length: 4.300837187789084
# Iters: 430
# Average most recent Z-score: 0.7041873999051294
# Average most recent stat-score: 0.252472779153961
# Average most recent p-value: 0.5204851389480711
# Average most recent clustering coeff: 0.6529274783932266
# Average most recent path length: 4.519426456984274
# Average most recent Z-score: 1.5050233836862557
# Average most recent stat-score: 0.4002719388454683
# Average most recent p-value: 0.16545586605786114
# Average most recent clustering coeff: 0.7404670959675151
# Average most recent path length: 4.3009065679926
# Iters: 440
# Average most recent Z-score: 0.6960339784159215
# Average most recent stat-score: 0.23855174422240988
# Average most recent p-value: 0.5653880352035542
# Average most recent clustering coeff: 0.654662652475181
# Average most recent path length: 4.479620721554117
# Average most recent Z-score: 1.4474080416602506
# Average most recent stat-score: 0.39017923008364186
# Average most recent p-value: 0.1773694103956941
# Average most recent clustering coeff: 0.7422019857204428
# Average most recent path length: 4.271313598519889
# Iters: 450
# Average most recent Z-score: 0.7166464342872766
# Average most recent stat-score: 0.2417269353098704
# Average most recent p-value: 0.554536071391211
# Average most recent clustering coeff: 0.6559889986381645
# Average most recent path length: 4.56786308973173
# Average most recent Z-score: 1.484705556664795
# Average most recent stat-score: 0.40484952547452546
# Average most recent p-value: 0.15317349220495255
# Average most recent clustering coeff: 0.7449563760021818
# Average most recent path length: 4.276401480111009
# Iters: 460
# Average most recent Z-score: 0.7214153372538664
# Average most recent stat-score: 0.245587996111216
# Average most recent p-value: 0.5485175114346478
# Average most recent clustering coeff: 0.656670889875765
# Average most recent path length: 4.534296947271045
# Average most recent Z-score: 1.4870276762136683
# Average most recent stat-score: 0.4160446906035141
# Average most recent p-value: 0.1381878378649824
# Average most recent clustering coeff: 0.7461492475890649
# Average most recent path length: 4.264616096207215
# Iters: 470
# Average most recent Z-score: 0.6929925594857277
# Average most recent stat-score: 0.24259878399893878
# Average most recent p-value: 0.553953162703418
# Average most recent clustering coeff: 0.6577859458601236
# Average most recent path length: 4.493413506012952
# Average most recent Z-score: 1.5393895357480485
# Average most recent stat-score: 0.4067599483849484
# Average most recent p-value: 0.149484399549167
# Average most recent clustering coeff: 0.7483940195467162
# Average most recent path length: 4.253320999074931
# Iters: 480
# Average most recent Z-score: 0.6673132759583527
# Average most recent stat-score: 0.24629649078991186
# Average most recent p-value: 0.5431714677327463
# Average most recent clustering coeff: 0.6581997727607319
# Average most recent path length: 4.512904717853839
# Average most recent Z-score: 1.512023042703448
# Average most recent stat-score: 0.40123788711288705
# Average most recent p-value: 0.15806712942464254
# Average most recent clustering coeff: 0.7498110449864441
# Average most recent path length: 4.2925901942645694
# Iters: 490
# Average most recent Z-score: 0.672782350744903
# Average most recent stat-score: 0.24064367774468395
# Average most recent p-value: 0.568786344011625
# Average most recent clustering coeff: 0.6594253498093512
# Average most recent path length: 4.514949121184088
# Average most recent Z-score: 1.4869228334345648
# Average most recent stat-score: 0.384504821159233
# Average most recent p-value: 0.18776142649292943
# Average most recent clustering coeff: 0.7525973284838677
# Average most recent path length: 4.2537742830712295

# %%
for res_e in res:    
    mins = []
    stat = []
    p = []
    cluss = []
    pplens = []
    for run in res_e:
        plens, clus_avgs, zs, samp = run
        mins.append(zs[-1])
        stat.append(samp[-1][0])
        p.append(samp[-1][1])
        cluss.append(clus_avgs[-1])
        pplens.append(plens[-1])

    print(f"Average most recent Z-score: {np.mean(mins)}")
    print(f"Average most recent stat-score: {np.mean(stat)}")
    print(f"Average most recent p-value: {np.mean(p)}")
    print(f"Average most recent clustering coeff: {np.mean(cluss)}")
    print(f"Average most recent path length: {np.mean(pplens)}")


    mins_b = []
    stat_b = []
    p_b = []
    cluss_b = []
    pplens_b = []    
    for run in res_e:
        plens, clus_avgs, zs, samp = run
        mins_b.append(np.min(zs))
        amin = np.argmax(zs) #Choose graph with most similar z-score
        stat_b.append(samp[amin][0])
        p_b.append(samp[amin][1])
        cluss_b.append(clus_avgs[amin])
        pplens_b.append(plens[amin // 5])

    print(f"Average best Z-score: {np.mean(mins_b)}")
    print(f"Average best stat-score: {np.mean(stat_b)}")
    print(f"Average best p-value: {np.mean(p_b)}")
    print(f"Average best clustering coeff: {np.mean(cluss_b)}")
    print(f"Average best path length: {np.mean(pplens_b)}")
    print("\n")

# %%
nAgents = 47
eps_funcs = np.random.uniform(0.2, 0.5, (nAgents,))
e_dist = lambda t, i : dist[i]
e_fixed = lambda t, i: 0.3
e_brainoff = lambda t, i: 1
world, plens, clus_avgs, zs, samp, hist_gs = monk_it_up(e_brainoff, 300, n  = 10,nAgents = 47, verbose = 1)

# %%
mins = []
stat = []
p = []
cluss = []
pplens = []
for run in res:
    world, plens, clus_avgs, zs, samp, hist_gs = run
    mins.append(zs[-1])
    stat.append(samp[-1][0])
    p.append(samp[-1][1])
    cluss.append(clus_avgs[-1])
    pplens.append(plens[-1])

# %%
worse_graph = nx.read_adjlist("./prog_g.adjlist")
print(f"Generated: {avg_path_length(world.G)}")
avg_path_length(worse_graph)

# %%
clus_avgs

# %%
print(np.min(zs))
samp[np.argmin(zs)]

# %%
plt.plot(zs)
plt.show()

# %%
degree_distribution(hist_gs[a])

# %%
degree_distribution(world.G)

# %%
worse_graph = nx.read_adjlist("./prog_g.adjlist")
w_degree_sequence = np.unique(sorted((d for _, d in worse_graph.degree()), reverse=True), return_counts = True)[1]


degree_sequence = np.unique(sorted((d for _, d in world.G.degree()), reverse=True),
                                        return_counts = True)[1]
top = (degree_sequence.mean() - w_degree_sequence.mean()) 
bot1 = np.square(np.std(degree_sequence) / np.sqrt(degree_sequence.shape[0]))
bot2 = np.square(np.std(w_degree_sequence)) / np.sqrt(w_degree_sequence.shape[0])
print(f"Z-score : {top / np.sqrt(bot1 + bot2)}")

ks_2samp(degree_sequence, w_degree_sequence)
print(f"ks_2 sample : {ks_2samp(degree_sequence, w_degree_sequence)}")

# %%
ks_2samp(degree_sequence, w_degree_sequence)

# %%
plens
